# %% [markdown]
# # Tabla 1 — Strack et al. (2014)
# **Lista de features y sus descripciones en el dataset inicial**
#
# Fuente:
# - BioMed Research International, DOI: 10.1155/2014/781670. Consultado online en https://onlinelibrary.wiley.com/doi/10.1155/2014/781670. Traducción vía elaboración propia
# ---
#
# <details>
# <summary><strong>Original</strong></summary>
#
# | Feature name | Dataset variable name | Type | Description and values | % missing |
# |---|---|---|---|---|
# | Encounter ID | `encounter_id` | Numeric | Unique identifier of an encounter | 0% |
# | Patient number | `patient_nbr` | Numeric | Unique identifier of a patient | 0% |
# | Race | `race` | Nominal | Values: Caucasian, Asian, African American, Hispanic, and other | 2% |
# | Gender | `gender` | Nominal | Values: male, female, and unknown/invalid | 0% |
# | Age | `age` | Nominal | Grouped in 10-year intervals: [0, 10), [10, 20), …, [90, 100) | 0% |
# | Weight | `weight` | Numeric | Weight in pounds | 97% |
# | Admission type | `admission_type_id` | Nominal | Integer identifier corresponding to 9 distinct values, for example, emergency, urgent, elective, newborn, and not available | 0% |
# | Discharge disposition | `discharge_disposition_id` | Nominal | Integer identifier corresponding to 29 distinct values, for example, discharged to home, expired, and not available | 0% |
# | Admission source | `admission_source_id` | Nominal | Integer identifier corresponding to 21 distinct values, for example, physician referral, emergency room, and transfer from a hospital | 0% |
# | Time in hospital | `time_in_hospital` | Numeric | Integer number of days between admission and discharge | 0% |
# | Payer code | `payer_code` | Nominal | Integer identifier corresponding to 23 distinct values, for example, Blue Cross/Blue Shield, Medicare, and self-pay | 52% |
# | Medical specialty | `medical_specialty` | Nominal | Integer identifier of a specialty of the admitting physician, corresponding to 84 distinct values, for example, cardiology, internal medicine, family/general practice, and surgeon | 53% |
# | Number of lab procedures | `num_lab_procedures` | Numeric | Number of lab tests performed during the encounter | 0% |
# | Number of procedures | `num_procedures` | Numeric | Number of procedures (other than lab tests) performed during the encounter | 0% |
# | Number of medications | `num_medications` | Numeric | Number of distinct generic names administered during the encounter | 0% |
# | Number of outpatient visits | `number_outpatient` | Numeric | Number of outpatient visits of the patient in the year preceding the encounter | 0% |
# | Number of emergency visits | `number_emergency` | Numeric | Number of emergency visits of the patient in the year preceding the encounter | 0% |
# | Number of inpatient visits | `number_inpatient` | Numeric | Number of inpatient visits of the patient in the year preceding the encounter | 0% |
# | Diagnosis 1 | `diag_1` | Nominal | The primary diagnosis (coded as first three digits of ICD9); 848 distinct values | 0% |
# | Diagnosis 2 | `diag_2` | Nominal | Secondary diagnosis (coded as first three digits of ICD9); 923 distinct values | 0% |
# | Diagnosis 3 | `diag_3` | Nominal | Additional secondary diagnosis (coded as first three digits of ICD9); 954 distinct values | 1% |
# | Number of diagnoses | `number_diagnoses` | Numeric | Number of diagnoses entered to the system | 0% |
# | Glucose serum test result | `max_glu_serum` | Nominal | Indicates the range of the result or if the test was not taken. Values: ">200", ">300", "normal", and "none" if not measured | 0% |
# | A1c test result | `A1Cresult` | Nominal | Indicates the range of the result or if the test was not taken. Values: ">8" if the result was greater than 8%, ">7" if the result was greater than 7% but less than 8%, "normal" if the result was less than 7%, and "none" if not measured | 0% |
# | Change of medications | `change` | Nominal | Indicates if there was a change in diabetic medications (either dosage or generic name). Values: "change" and "no change" | 0% |
# | Diabetes medications | `diabetesMed` | Nominal | Indicates if there was any diabetic medication prescribed. Values: "yes" and "no" | 0% |
# | 24 features for medications | `metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone` | Nominal | For each drug, indicates whether it was prescribed or there was a change in the dosage. Values: "up" if the dosage was increased, "down" if decreased, "steady" if unchanged, and "no" if not prescribed | 0% |
# | Readmitted | `readmitted` | Nominal | Days to inpatient readmission. Values: "<30" if the patient was readmitted in less than 30 days, ">30" if readmitted in more than 30 days, and "No" for no record of readmission | 0% |
#
# </details>
#
# ---
#
# <details>
# <summary><strong>Traducción español</strong></summary>
#
# | Feature name | Nombre en el dataset | Tipo | Descripción y valores | % faltante |
# |---|---|---|---|---|
# | Encounter ID | `encounter_id` | Numérico | Identificador único de un encuentro | 0% |
# | Patient number | `patient_nbr` | Numérico | Identificador único de un paciente | 0% |
# | Race | `race` | Nominal | Valores: Caucásico, Asiático, Afroamericano, Hispano y otro | 2% |
# | Gender | `gender` | Nominal | Valores: masculino, femenino e inválido/desconocido | 0% |
# | Age | `age` | Nominal | Agrupada en intervalos de 10 años: [0, 10), [10, 20), …, [90, 100) | 0% |
# | Weight | `weight` | Numérico | Peso en libras | 97% |
# | Admission type | `admission_type_id` | Nominal | Identificador entero correspondiente a 9 valores distintos, por ejemplo, emergencia, urgente, electivo, recién nacido y no disponible | 0% |
# | Discharge disposition | `discharge_disposition_id` | Nominal | Identificador entero correspondiente a 29 valores distintos, por ejemplo, dado de alta a domicilio, fallecido y no disponible | 0% |
# | Admission source | `admission_source_id` | Nominal | Identificador entero correspondiente a 21 valores distintos, por ejemplo, derivación médica, guardia y traslado desde otro hospital | 0% |
# | Time in hospital | `time_in_hospital` | Numérico | Número entero de días entre la admisión y el alta | 0% |
# | Payer code | `payer_code` | Nominal | Identificador entero correspondiente a 23 valores distintos, por ejemplo, Blue Cross/Blue Shield, Medicare y pago propio | 52% |
# | Medical specialty | `medical_specialty` | Nominal | Identificador entero de la especialidad del médico que admite al paciente, correspondiente a 84 valores distintos, por ejemplo, cardiología, medicina interna, medicina general/familiar y cirugía | 53% |
# | Number of lab procedures | `num_lab_procedures` | Numérico | Cantidad de análisis de laboratorio realizados durante el encuentro | 0% |
# | Number of procedures | `num_procedures` | Numérico | Cantidad de procedimientos (distintos de los de laboratorio) realizados durante el encuentro | 0% |
# | Number of medications | `num_medications` | Numérico | Cantidad de nombres genéricos distintos administrados durante el encuentro | 0% |
# | Number of outpatient visits | `number_outpatient` | Numérico | Cantidad de visitas ambulatorias del paciente en el año previo al encuentro | 0% |
# | Number of emergency visits | `number_emergency` | Numérico | Cantidad de visitas a urgencias del paciente en el año previo al encuentro | 0% |
# | Number of inpatient visits | `number_inpatient` | Numérico | Cantidad de internaciones del paciente en el año previo al encuentro | 0% |
# | Diagnosis 1 | `diag_1` | Nominal | Diagnóstico principal (codificado con los primeros tres dígitos del ICD9); 848 valores distintos | 0% |
# | Diagnosis 2 | `diag_2` | Nominal | Diagnóstico secundario (codificado con los primeros tres dígitos del ICD9); 923 valores distintos | 0% |
# | Diagnosis 3 | `diag_3` | Nominal | Diagnóstico secundario adicional (codificado con los primeros tres dígitos del ICD9); 954 valores distintos | 1% |
# | Number of diagnoses | `number_diagnoses` | Numérico | Cantidad de diagnósticos ingresados al sistema | 0% |
# | Glucose serum test result | `max_glu_serum` | Nominal | Indica el rango del resultado o si el test no fue realizado. Valores: ">200", ">300", "normal" y "ninguno" si no fue medido | 0% |
# | A1c test result | `A1Cresult` | Nominal | Indica el rango del resultado o si el test no fue realizado. Valores: ">8" si el resultado fue mayor al 8%, ">7" si fue mayor al 7% pero menor al 8%, "normal" si fue menor al 7%, y "ninguno" si no fue medido | 0% |
# | Change of medications | `change` | Nominal | Indica si hubo un cambio en los medicamentos para diabetes (ya sea en la dosis o en el nombre genérico). Valores: "cambio" y "sin cambio" | 0% |
# | Diabetes medications | `diabetesMed` | Nominal | Indica si se prescribió algún medicamento para diabetes. Valores: "sí" y "no" | 0% |
# | 24 features for medications | `metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone` | Nominal | Para cada medicamento, indica si fue prescrito o si hubo un cambio en la dosis. Valores: "subida" si la dosis aumentó, "bajada" si disminuyó, "estable" si no cambió, y "no" si no fue prescrito | 0% |
# | Readmitted | `readmitted` | Nominal | Días hasta la readmisión como paciente internado. Valores: "<30" si el paciente fue readmitido en menos de 30 días, ">30" si fue readmitido después de 30 días, y "No" si no hay registro de readmisión | 0% |
#
# </details>
