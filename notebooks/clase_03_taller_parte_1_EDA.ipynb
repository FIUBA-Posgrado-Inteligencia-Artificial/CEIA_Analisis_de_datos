# %% [markdown]
# ## Análisis de datos - Clase 3

# %% [markdown]
# # Taller práctico - análisis de un dataset

# %% [markdown]
# En esta clase vamos a analizar en forma completa un dataset con datos de Fórmula 1 de la temporada 2024 (los datos fueron extraídos con la biblioteca Fastf1). El dataset contiene información sobre las carreras, los pilotos, los tiempos y los resultados de cada evento.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno

# %%
# Dataset de carreras del 2024
raw_carreras_24 = pd.read_csv('../datasets/f1_2024_R.csv')

# %% [markdown]
# ---
# ## EDA (Exploratory Data Analysis)
# ---

# %% [markdown]
# ### Columnas y tipos de datos

# %%
raw_carreras_24.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'EventName', 'SessionType',
#        'EventDate', 'Time_weather', 'AirTemp', 'TrackTemp', 'Humidity',
#        'AvgSpeed', 'MaxThrottle', 'AvgBrake'],
#       dtype='object')

# %%
# Armamos un nuevo dataset con menos columnas para el análisis
carreras_24 = raw_carreras_24.drop(columns=['Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
        'SessionType', 'AvgSpeed', 'MaxThrottle', 'AvgBrake', 'Time_weather'], axis=1)

# %%
carreras_24.shape
# Out:
# (26606, 32)

# %%
carreras_24.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'SpeedI1',
#        'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest', 'Compound',
#        'TyreLife', 'FreshTyre', 'Team', 'LapStartTime', 'LapStartDate',
#        'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'EventName', 'EventDate', 'AirTemp',
#        'TrackTemp', 'Humidity'],
#       dtype='object')

# %% [markdown]
# ### Detalles de las columnas del dataset
#
# #### Evento
# * EventName
# * EventDate
#
# #### Corredor y equipo
# * Driver: nombre del piloto
# * DriverNumber: número del piloto
# * Team: nombre del equipo constructor
# * Grid: posición de salida (1,2,3, etc.) ### ????
#
# #### Vueltas y tiempos
# * PitInLap: tiempo desde el comienzo de la vuelta en el que el piloto entra en boxes (timedelta).
# * PitOutLap: tiempo desde el comienzo de la vuelta en el que el piloto sale de boxes (timedelta).
# * IsPersonalBest: indica si la vuelta fue la mejor del piloto en la sesión (1,0)
# * Stint: indica el cambio de cubiertas (1,2,3, etc.)
# * LapTime: tiempo de la vuelta (en segundos)
# * LapNumber: número de vuelta (1,2,3, etc.)
# * LapStartTime
# * LapStartDate
# * Sector1Time
# * Sector2Time
# * Sector3Time
#
# #### Telemetría
#
# * SpeedI1, SpeedI2: velocidad en dos puntos intermedio de la vuelta (km/h)
# * SpeedFL: velocidad en la línea de meta (km/h)
# * SpeedST: velocidad en el speed trap que es el punto más rápido en la recta (km/h)
#
# #### Condiciones climáticas
# * AirTemp: temperatura del aire (°C)
# * TrackTemp: temperatura de la pista (°C)
# * Humidity: humedad (%)
#
# #### Cubiertas
# * Compound: tipo de cubierta (Duro, Medio, Blando, de lluvia, etc.)
# * TyreLife: vida útil de la cubierta (número de vueltas)
# * FreshTyre: indica si la cubierta es nueva o usada (1,0)
#
# #### Contexto
#
# * TrackStatus: las condiciones de la pista (1 para verde, 2 para amarilla, 4 para Safety Car)
# * Position: la posición del piloto al final de la vuelta (1,2,3, etc.)
# * Deleted: indica si la vuelta fue eliminada (por alguna infracción, por ejemplo, por exceder los límites de la pista)
# * DeletedReason: la razon por la que la vuelta fue eliminada (por ejemplo, por exceder los límites de la pista)
# * FastF1Generated: indica si los datos fueron generados por FastF1 (por ejemplo, si la telemetría está incompleta)
# * IsAccurate: indica si los datos son confiables (por ejemplo, si no hay interpolación)

# %%
# Reordeno las columnas para poder identificarlas y analizarlas más cómodamente 
nuevo_orden = ['EventName', 'EventDate',                           # Evento
               'Driver', 'DriverNumber', 'Team',                   # Corredor y equipo               
               'PitInTime', 'PitOutTime', 'IsPersonalBest',        # Vueltas y tiempos
               'Stint', 'LapTime', 'LapNumber',
               'LapStartTime', 'LapStartDate',
               'Sector1Time', 'Sector2Time', 'Sector3Time',
               'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST',         # Telemetría
               'AirTemp', 'TrackTemp', 'Humidity',                 # Condiciones climáticas
               'Compound', 'TyreLife', 'FreshTyre',                # Cubiertas

               'TrackStatus', 'Position',                          # Contexto
               'Deleted', 'DeletedReason',
               'FastF1Generated', 'IsAccurate'
]
carreras_24 = carreras_24[nuevo_orden]

# %% [markdown]
# ### Vista general del dataset

# %%
carreras_24.head(10)
# Out:
#             EventName   EventDate Driver  DriverNumber             Team  \
# 0  Bahrain Grand Prix  2024-03-02    VER             1  Red Bull Racing
# 1  Bahrain Grand Prix  2024-03-02    LEC            16          Ferrari
# 2  Bahrain Grand Prix  2024-03-02    RUS            63         Mercedes
# 3  Bahrain Grand Prix  2024-03-02    NOR             4          McLaren
# 4  Bahrain Grand Prix  2024-03-02    HAM            44         Mercedes
# 5  Bahrain Grand Prix  2024-03-02    PIA            81          McLaren
# 6  Bahrain Grand Prix  2024-03-02    ALO            14     Aston Martin
# 7  Bahrain Grand Prix  2024-03-02    SAR             2         Williams
# 8  Bahrain Grand Prix  2024-03-02    SAI            55          Ferrari
# 9  Bahrain Grand Prix  2024-03-02    ZHO            24      Kick Sauber
#
#   PitInTime PitOutTime IsPersonalBest  Stint  LapTime  ...  Humidity  \
# 0       NaN        NaN          False    1.0   97.284  ...      49.0
# 1       NaN        NaN          False    1.0   98.271  ...      49.0
# 2       NaN        NaN          False    1.0   99.228  ...      49.0
# 3       NaN        NaN          False    1.0  102.168  ...      49.0
# 4       NaN        NaN          False    1.0  103.122  ...      49.0
# 5       NaN        NaN          False    1.0  102.523  ...      49.0
# 6       NaN        NaN          False    1.0  101.679  ...      49.0
# 7       NaN        NaN          False    1.0  105.921  ...      49.0
# 8       NaN        NaN          False    1.0  100.620  ...      49.0
# 9       NaN        NaN          False    1.0  104.801  ...      49.0
#
#    Compound TyreLife  FreshTyre  TrackStatus  Position  Deleted  \
# 0      SOFT      4.0      False           12       1.0    False
# 1      SOFT      4.0      False           12       2.0    False
# 2      SOFT      4.0      False           12       3.0    False
# 3      SOFT      4.0      False           12       7.0    False
# 4      SOFT      4.0      False           12       9.0    False
# 5      SOFT      4.0      False           12       8.0    False
# 6      SOFT      4.0      False           12       6.0    False
# 7      SOFT      1.0       True           12      15.0    False
# 8      SOFT      4.0      False           12       5.0    False
# 9      SOFT      1.0       True           12      13.0    False
#
#    DeletedReason  FastF1Generated  IsAccurate
# 0            NaN            False       False
# 1            NaN            False       False
# 2            NaN            False       False
# 3            NaN            False       False
# 4            NaN            False       False
# 5            NaN            False       False
# 6            NaN            False       False
# 7            NaN            False       False
# 8            NaN            False       False
# 9            NaN            False       False
#
# [10 rows x 32 columns]

# %%
carreras_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26606 entries, 0 to 26605
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EventName        26606 non-null  object
#  1   EventDate        26606 non-null  object
#  2   Driver           26606 non-null  object
#  3   DriverNumber     26606 non-null  int64
#  4   Team             26606 non-null  object
#  5   PitInTime        849 non-null    object
#  6   PitOutTime       840 non-null    object
#  7   IsPersonalBest   26591 non-null  object
#  8   Stint            26606 non-null  float64
#  9   LapTime          26381 non-null  float64
#  10  LapNumber        26606 non-null  float64
#  11  LapStartTime     26606 non-null  float64
#  12  LapStartDate     26591 non-null  object
#  13  Sector1Time      26066 non-null  float64
#  14  Sector2Time      26574 non-null  float64
#  15  Sector3Time      26553 non-null  float64
#  16  SpeedI1          22460 non-null  float64
#  17  SpeedI2          26552 non-null  float64
#  18  SpeedFL          25728 non-null  float64
#  19  SpeedST          24422 non-null  float64
#  20  AirTemp          26606 non-null  float64
#  21  TrackTemp        26606 non-null  float64
#  22  Humidity         26606 non-null  float64
#  23  Compound         26606 non-null  object
#  24  TyreLife         26606 non-null  float64
#  25  FreshTyre        26606 non-null  bool
#  26  TrackStatus      26606 non-null  int64
#  27  Position         26578 non-null  float64
#  28  Deleted          26606 non-null  bool
#  29  DeletedReason    326 non-null    object
#  30  FastF1Generated  26606 non-null  bool
#  31  IsAccurate       26606 non-null  bool
# dtypes: bool(4), float64(16), int64(2), object(10)
# memory usage: 5.8+ MB

# %%
# Me fijo si hay algún valor raro en posición
carreras_24[(carreras_24['Position'] < 1) | (carreras_24['Position'] > 20)]
# Out:
# Empty DataFrame
# Columns: [EventName, EventDate, Driver, DriverNumber, Team, PitInTime, PitOutTime, IsPersonalBest, Stint, LapTime, LapNumber, LapStartTime, LapStartDate, Sector1Time, Sector2Time, Sector3Time, SpeedI1, SpeedI2, SpeedFL, SpeedST, AirTemp, TrackTemp, Humidity, Compound, TyreLife, FreshTyre, TrackStatus, Position, Deleted, DeletedReason, FastF1Generated, IsAccurate]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# ### Ajustamos los tipos de datos

# %%
# Categóricas
carreras_24['EventName'] = carreras_24['EventName'].astype('category')
carreras_24['Driver'] = carreras_24['Driver'].astype('category')
carreras_24['DriverNumber'] = carreras_24['DriverNumber'].astype('category')
carreras_24['Team'] = carreras_24['Team'].astype('category')
carreras_24['FreshTyre'] = carreras_24['FreshTyre'].astype('category')
carreras_24['TyreLife'] = carreras_24['TyreLife'].astype('category')
carreras_24['Compound'] = carreras_24['Compound'].astype('category')
carreras_24['Stint'] = carreras_24['Stint'].astype('category')
carreras_24['IsPersonalBest'] = carreras_24['IsPersonalBest'].astype('category')
carreras_24['Deleted'] = carreras_24['Deleted'].astype('category')
carreras_24['DeletedReason'] = carreras_24['DeletedReason'].astype('category')
carreras_24['TrackStatus'] = carreras_24['TrackStatus'].astype('category')
carreras_24['FastF1Generated'] = carreras_24['FastF1Generated'].astype('category')
carreras_24['IsAccurate'] = carreras_24['IsAccurate'].astype('category')

# Categórica ordinal
posicion_orden = list(range(1, 21))
carreras_24['Position'] = pd.Categorical(carreras_24['Position'], categories=posicion_orden, ordered=True) 


# Numéricas temporales
carreras_24['EventDate'] = pd.to_datetime(carreras_24['EventDate'])
carreras_24['PitInTime'] = pd.to_timedelta(carreras_24['PitInTime'])
carreras_24['PitOutTime'] = pd.to_timedelta(carreras_24['PitOutTime'])
carreras_24['LapStartDate'] = pd.to_datetime(carreras_24['LapStartDate'])

# Numéricas discretas
carreras_24['LapNumber'] = carreras_24['LapNumber'].astype('int')

# %%
carreras_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26606 entries, 0 to 26605
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EventName        26606 non-null  category
#  1   EventDate        26606 non-null  datetime64[ns]
#  2   Driver           26606 non-null  category
#  3   DriverNumber     26606 non-null  category
#  4   Team             26606 non-null  category
#  5   PitInTime        849 non-null    timedelta64[ns]
#  6   PitOutTime       840 non-null    timedelta64[ns]
#  7   IsPersonalBest   26591 non-null  category
#  8   Stint            26606 non-null  category
#  9   LapTime          26381 non-null  float64
#  10  LapNumber        26606 non-null  int64
#  11  LapStartTime     26606 non-null  float64
#  12  LapStartDate     26591 non-null  datetime64[ns]
#  13  Sector1Time      26066 non-null  float64
#  14  Sector2Time      26574 non-null  float64
#  15  Sector3Time      26553 non-null  float64
#  16  SpeedI1          22460 non-null  float64
#  17  SpeedI2          26552 non-null  float64
#  18  SpeedFL          25728 non-null  float64
#  19  SpeedST          24422 non-null  float64
#  20  AirTemp          26606 non-null  float64
#  21  TrackTemp        26606 non-null  float64
#  22  Humidity         26606 non-null  float64
#  23  Compound         26606 non-null  category
#  24  TyreLife         26606 non-null  category
#  25  FreshTyre        26606 non-null  category
#  26  TrackStatus      26606 non-null  category
#  27  Position         26578 non-null  category
#  28  Deleted          26606 non-null  category
#  29  DeletedReason    326 non-null    category
#  30  FastF1Generated  26606 non-null  category
#  31  IsAccurate       26606 non-null  category
# dtypes: category(15), datetime64[ns](2), float64(12), int64(1), timedelta64[ns](2)
# memory usage: 3.9 MB

# %% [markdown]
# ---

# %% [markdown]
# ---
# ### Variables categóricas: exploración
# ---

# %%
carreras_24[carreras_24['Position'] == '0']
# Out:
# Empty DataFrame
# Columns: [EventName, EventDate, Driver, DriverNumber, Team, PitInTime, PitOutTime, IsPersonalBest, Stint, LapTime, LapNumber, LapStartTime, LapStartDate, Sector1Time, Sector2Time, Sector3Time, SpeedI1, SpeedI2, SpeedFL, SpeedST, AirTemp, TrackTemp, Humidity, Compound, TyreLife, FreshTyre, TrackStatus, Position, Deleted, DeletedReason, FastF1Generated, IsAccurate]
# Index: []
#
# [0 rows x 32 columns]

# %%
carreras_24.describe(include='category')
# Out:
#                EventName Driver  DriverNumber     Team IsPersonalBest  \
# count              26606  26606         26606    26606          26591
# unique                24     24            25       10              2
# top     Dutch Grand Prix    PIA            81  McLaren          False
# freq                1426   1444          1444     2881          21094
#
#           Stint Compound  TyreLife FreshTyre  TrackStatus  Position Deleted  \
# count   26606.0    26606   26606.0     26606        26606     26578   26606
# unique      5.0        6      78.0         2           25        20       2
# top         2.0     HARD       4.0      True            1         6   False
# freq    11438.0    13767    1162.0     21042        24604      1444   26280
#
#                          DeletedReason FastF1Generated IsAccurate
# count                              326           26606      26606
# unique                             255               2          2
# top     TRACK LIMITS AT TURN 1 LAP 10            False       True
# freq                                 5           26578      23557

# %% [markdown]
# #### Evento

# %%
# Grand Prix que se corrieron en el 2024
carreras_24['EventName'].unique()
# Out:
# ['Bahrain Grand Prix', 'Saudi Arabian Grand Prix', 'Australian Grand Prix', 'Japanese Grand Prix', 'Chinese Grand Prix', ..., 'Mexico City Grand Prix', 'São Paulo Grand Prix', 'Las Vegas Grand Prix', 'Qatar Grand Prix', 'Abu Dhabi Grand Prix']
# Length: 24
# Categories (24, object): ['Abu Dhabi Grand Prix', 'Australian Grand Prix', 'Austrian Grand Prix', 'Azerbaijan Grand Prix', ..., 'Singapore Grand Prix', 'Spanish Grand Prix', 'São Paulo Grand Prix', 'United States Grand Prix']

# %% [markdown]
# #### Corredor y equipo

# %%
# Pilotos que corrieron en el 2024
carreras_24['Driver'].unique()
# Out:
# ['VER', 'LEC', 'RUS', 'NOR', 'HAM', ..., 'STR', 'BEA', 'COL', 'LAW', 'DOO']
# Length: 24
# Categories (24, object): ['ALB', 'ALO', 'BEA', 'BOT', ..., 'STR', 'TSU', 'VER', 'ZHO']

# %%
# Equipos
carreras_24['Team'].unique()
# Out:
# ['Red Bull Racing', 'Ferrari', 'Mercedes', 'McLaren', 'Aston Martin', 'Williams', 'Kick Sauber', 'RB', 'Haas F1 Team', 'Alpine']
# Categories (10, object): ['Alpine', 'Aston Martin', 'Ferrari', 'Haas F1 Team', ..., 'Mercedes', 'RB', 'Red Bull Racing', 'Williams']

# %% [markdown]
# #### Cubiertas

# %%
carreras_24['Compound'].unique()
# Out:
# ['SOFT', 'HARD', 'MEDIUM', 'INTERMEDIATE', 'WET', 'UNKNOWN']
# Categories (6, object): ['HARD', 'INTERMEDIATE', 'MEDIUM', 'SOFT', 'UNKNOWN', 'WET']

# %%
#fig, ax = plt.subplots(2, 2, figsize=(10, 8))
sns.countplot(data=carreras_24, x='Compound', color="lightblue")
# Out:
# <Axes: xlabel='Compound', ylabel='count'>

# %%
carreras_24['FreshTyre'].unique()
# Out:
# [False, True]
# Categories (2, bool): [False, True]

# %%
carreras_24['TyreLife'].unique()
# Out:
# [4.0, 1.0, 5.0, 2.0, 6.0, ..., 74.0, 75.0, 76.0, 77.0, 78.0]
# Length: 78
# Categories (78, float64): [1.0, 2.0, 3.0, 4.0, ..., 75.0, 76.0, 77.0, 78.0]

# %% [markdown]
# #### Contexto

# %% [markdown]
# **Variable TrackStatus**
#
# Valores conocidos (https://docs.fastf1.dev/api.html#fastf1.api.track_status_data)
#
# * 1: Track clear (beginning of session or to indicate the end of another status)
# * 2: Yellow flag (sectors are unknown)
# * 3: ??? Never seen so far, does not exist?
# * 4: Safety Car
# * 5: Red Flag
# * 6: Virtual Safety Car deployed
# * 7: Virtual Safety Car ending (As indicated on the drivers steering wheel, on tv and so on; status ‘1’ will mark the actual end)

# %%
carreras_24['TrackStatus'].unique()
# Out:
# [12, 1, 21, 124, 24, ..., 412, 267, 45, 51, 1264]
# Length: 25
# Categories (25, int64): [1, 4, 6, 12, ..., 1254, 1264, 1267, 2671]

# %%
sns.set_theme(font_scale=0.6)
sns.countplot(data=carreras_24, x= 'TrackStatus', stat='percent' )
# Out:
# <Axes: xlabel='TrackStatus', ylabel='percent'>

# %% [markdown]
# ---
# ### Variables numéricas: estadística descriptiva
# ---

# %%
# Para usar una función custom que guardé en utils
import sys
import os

# Agrego el path para poder importar utils
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils.plotting import plot_histograma

# %%
carreras_24.describe()
# Out:
#                            EventDate                  PitInTime  \
# count                          26606                        849
# mean   2024-07-20 19:42:45.165752064  0 days 01:36:26.654181389
# min              2024-03-02 00:00:00     0 days 00:15:20.353000
# 25%              2024-05-19 00:00:00     0 days 01:16:58.954000
# 50%              2024-07-07 00:00:00     0 days 01:38:45.781000
# 75%              2024-09-22 00:00:00     0 days 01:53:19.090000
# max              2024-12-08 00:00:00     0 days 03:10:59.688000
# std                              NaN  0 days 00:24:02.916710214
#
#                       PitOutTime       LapTime     LapNumber  LapStartTime  \
# count                        840  26381.000000  26606.000000  26606.000000
# mean   0 days 01:37:42.147103571     92.727333     30.507931   6191.722126
# min       0 days 00:04:17.809000     67.694000      1.000000    245.608000
# 25%       0 days 01:18:31.260750     81.964000     15.000000   4707.357750
# 50%       0 days 01:38:21.220500     89.076000     30.000000   6136.312500
# 75%       0 days 01:53:11.494750     98.704000     45.000000   7584.237750
# max       0 days 03:11:24.136000   2526.253000     78.000000  11925.420000
# std       0 days 00:24:21.070185     60.498621     18.260169   1929.832188
#
#                         LapStartDate   Sector1Time   Sector2Time  \
# count                          26591  26066.000000  26574.000000
# mean   2024-07-21 10:47:01.542331648     28.544514     35.105664
# min       2024-03-02 15:03:42.342000     16.897000     17.488000
# 25%    2024-05-19 13:42:25.069499904     25.398250     29.584000
# 50%       2024-07-07 15:08:57.716000     28.470000     32.958000
# 75%    2024-09-22 13:16:06.315500032     31.086000     41.288000
# max       2024-12-08 14:30:04.406000     97.585000     90.308000
# std                              NaN      6.928019      7.506386
#
#         Sector3Time       SpeedI1       SpeedI2       SpeedFL       SpeedST  \
# count  26553.000000  22460.000000  26552.000000  25728.000000  24422.000000
# mean      27.942290    254.994167    247.649292    268.093711    296.643928
# min       17.690000     59.000000     57.000000      1.000000     64.000000
# 25%       23.076000    214.000000    211.000000    248.000000    289.000000
# 50%       25.949000    273.000000    257.000000    275.000000    302.000000
# 75%       31.986000    289.000000    280.000000    291.000000    313.000000
# max       97.241000    357.000000    343.000000    357.000000    362.000000
# std        7.434872     45.269851     43.887292     34.744874     31.732479
#
#             AirTemp     TrackTemp      Humidity
# count  26606.000000  26606.000000  26606.000000
# mean      23.490434     35.588191     54.358303
# min       14.500000     16.700000     30.000000
# 25%       19.200000     28.700000     45.000000
# 50%       22.000000     37.000000     53.000000
# 75%       28.300000     43.500000     63.000000
# max       33.900000     51.700000     92.000000
# std        4.789366      9.032689     13.877374

# %% [markdown]
# #### Histogramas

# %%
plot_histograma(carreras_24, column='LapTime', figsize=(8,5), bins=50, mvd=False)

# %%
plot_histograma(carreras_24, column='AirTemp', bins=15, mvd=False)

# %%
plot_histograma(carreras_24, column='TrackTemp', bins=15, mvd=False)

# %%
plot_histograma(carreras_24, column='Humidity', bins=15, mvd=False)

# %%
# Velocidad al cruzar la meta
plot_histograma(carreras_24, column='SpeedFL', bins=15, mvd=False)

# %%
# Velocidad en el speed trap (la parte más rápida de la pista)
plot_histograma(carreras_24, column='SpeedST', bins=15, mvd=False)

# %% [markdown]
# #### Boxplots

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
sns.boxplot(data=carreras_24, y='LapTime', color="lightblue", ax=ax[0])
sns.boxplot(data=carreras_24, y='LapTime', color="lightblue", showfliers= False, ax=ax[1])       
ax[0].grid(axis='y', ls='--')
ax[0].set_title('Boxplot para LapTime', fontsize=12)
ax[1].grid(axis='y', ls='--')
ax[1].set_title('Boxplot para LapTime sin mostrar outliers', fontsize=12)

plt.show()

# %% [markdown]
# Nota: observar que este boxplot muestra la dispersión del tiempo de vuelta pero considerando TODAS las carreras juntas.

# %% [markdown]
# ---
# ### Visualizaciones entre pares de variables
# ---

# %% [markdown]
# #### 1) Carreras
# ---

# %%
carreras_24.groupby(['EventName'], observed=True)['LapNumber'].max().sort_values().plot(kind='barh', colormap='Pastel2' , title='Nro. de vueltas por circuito')
# Out:
# <Axes: title={'center': 'Nro. de vueltas por circuito'}, ylabel='EventName'>

# %%
# Tiempo de vuuelta por carrera

sns.boxplot(data=carreras_24, x='LapTime', y='EventName', color="lightblue", showfliers=False)
plt.title('Boxplots de LapTime (en seg) para cada carrera',fontsize=12)
# Out:
# Text(0.5, 1.0, 'Boxplots de LapTime (en seg) para cada carrera')

# %% [markdown]
# #### 2) Condiciones de la pista
# ---

# %%
sns.boxplot(data=carreras_24, x='TrackTemp', y='EventName', color="lightblue", showfliers=False)
plt.title('Boxplots de TrackTemp (°C) para cada carrera')
# Out:
# Text(0.5, 1.0, 'Boxplots de TrackTemp (°C) para cada carrera')

# %% [markdown]
# #### 2) Performance de los pilotos
# ---

# %%
fig, ax = plt.subplots(3, 1,figsize=(20, 18))

sns.boxplot(data=carreras_24, y='Sector1Time', x='Driver', ax=ax[0])
sns.boxplot(data=carreras_24, y='Sector2Time', x='Driver', ax=ax[1])
sns.boxplot(data=carreras_24, y='Sector3Time', x='Driver', ax=ax[2])

for i in (0,1,2):
    ax[i].grid(axis='y', ls='--')
    ax[i].set_title(f'Tiempos del sector {i+1} para cada piloto', fontsize=15)

plt.show()

# %% [markdown]
# Nota: Aquí vemos la dispersión de los tiempos de cada piloto para cada sector. Es importante tener en cuenta que estamos viendo los tiempos para todas las carreras juntas (y no todos los circuitos son iguales en longitud)

# %% [markdown]
# #### Tiempos por sector para un piloto y circuito determinado

# %%
# Función auxiliar para graficar los tiempos por vuelta de cada piloto, para cada sector. Se puede graficar para una carrera o para todas juntas
def scatter(driver, race='all'):
    if race == 'all':
        df = carreras_24[carreras_24['Driver']==driver]
    else:
        df = carreras_24[(carreras_24['Driver']==driver) & (carreras_24['EventName']==race)]

    plt.figure(figsize=(10, 5))
    plt.scatter(df['LapNumber'], df['Sector1Time'], label='Sector 1', alpha=0.7)
    plt.scatter(df['LapNumber'], df['Sector2Time'], label='Sector 2', alpha=0.7)
    plt.scatter(df['LapNumber'], df['Sector3Time'], label='Sector 3', alpha=0.7)

    plt.xlabel('')
    plt.ylabel('Time')
    plt.title(f'Tiempos por sector - Piloto: {driver} - Carrera(s): {race}', fontsize=12)
    plt.legend()
    plt.xticks(list(range(1,85,3)))
    plt.show()

# %%
scatter('NOR', 'Australian Grand Prix')

# %%
scatter('RUS', 'Australian Grand Prix')

# %% [markdown]
# Obs: pareciera haber sucedido algo en la vuelta 17 porque ambos pilotos muestran tiempos más altos.

# %%
scatter('VER', 'Australian Grand Prix')

# %% [markdown]
# Nota: No hay datos de Verstappen más allá de la vuelta 4 - DNF?

# %% [markdown]
# #### Vista general de las vueltas completadas en cada carrera

# %%
# Pilotos por equipo por carrera

plt.figure(figsize=(10, 10))
cross_tab = pd.crosstab([carreras_24['Driver'], carreras_24['Team']], carreras_24['EventName'])
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='Blues')
plt.title('Vueltas los pilotos/equipos en cada carrera', fontsize=14)
plt.xlabel('Gran premio', fontsize=12)
plt.ylabel('Piloto-Equipo', fontsize=12)
plt.show()

# %% [markdown]
# #### Resumen de carreras en los que participó cada piloto durante el 2024

# %%
# Total de carreras en las que participó cada piloto
driver_events = carreras_24.groupby('Driver', observed=True)['EventName'].nunique().reset_index()
driver_events = driver_events.sort_values(ascending=False, by='EventName')

driver_events.plot.barh(x='Driver', y='EventName', figsize=(8, 6))
plt.xlabel('Cantidad de eventos')
plt.title('Eventos por piloto')
plt.show()

# %% [markdown]
# #### ¿Para qué equipos corrió cada piloto en 2024?

# %%
# ¿En cuántos equipos estuvo cada piloto?
teams = carreras_24.groupby('Driver', observed=True)['Team'].nunique().reset_index()
teams.plot(kind='bar', x='Driver', y='Team', figsize=(10, 4), legend=False)
plt.show()

# %%
#!conda install networkx
#!poetry add networkx

# %%
import networkx as nx
from networkx.drawing.layout import bipartite_layout

# %%
# Otro tipo de visualización: grafo bipartito entre pilotos y equipos

# Crear grafo
G = nx.Graph()
pares = carreras_24[['Driver', 'Team']].drop_duplicates()
pilotos = pares['Driver'].unique()
equipos = pares['Team'].unique()

G.add_nodes_from(pilotos, bipartite=0)
G.add_nodes_from(equipos, bipartite=1)
G.add_edges_from(list(pares.itertuples(index=False, name=None)))

# Layout bipartito
pos = bipartite_layout(G, pilotos)

# Figura
plt.figure(figsize=(10, 6))
nx.draw(G, pos,
        with_labels=True,
        node_size=2000,
        node_color=['#66c2a5' if n in pilotos else '#fc8d62' for n in G.nodes()],
        edge_color='gray',
        font_size=8)

plt.title('Relación entre pilotos y equipos')
plt.axis('off')
plt.show()

# %% [markdown]
# ---
# ## Datos faltantes
# ---

# %% [markdown]
# #### Calculo el total de datos faltantes

# %%
# Serie con los valores faltantes
faltantes = carreras_24.isna().sum()

# Calculamos porcentaje de valores faltantes
total_filas = len(carreras_24)
faltantes_df = faltantes.to_frame(name='faltantes')
faltantes_df['porcentaje'] = ((faltantes_df['faltantes'] / total_filas) * 100).round(2)
faltantes_df = faltantes_df.sort_values(by='faltantes', ascending=False)

# Mostramos solo las que tienen valores faltantes
faltantes_df[faltantes_df['faltantes'] > 0]
# Out:
#                 faltantes  porcentaje
# DeletedReason       26280       98.77
# PitOutTime          25766       96.84
# PitInTime           25757       96.81
# SpeedI1              4146       15.58
# SpeedST              2184        8.21
# SpeedFL               878        3.30
# Sector1Time           540        2.03
# LapTime               225        0.85
# SpeedI2                54        0.20
# Sector3Time            53        0.20
# Sector2Time            32        0.12
# Position               28        0.11
# IsPersonalBest         15        0.06
# LapStartDate           15        0.06

# %%
msno.bar(carreras_24, figsize=(12, 6), fontsize=10)
# Out:
# <Axes: >

# %%
msno.matrix(carreras_24, figsize=(12, 6), sparkline=True, fontsize=10)
# Out:
# <Axes: >

# %%
msno.heatmap(carreras_24, figsize=(12, 6), fontsize=12)
# Out:
# <Axes: >

# %% [markdown]
# Obs:
# * Sector1Time tiene 2% de datos faltantes pero no parece tener relación sustancial con los faltantes de ninguna otra columna.
# * Sector2Time y 3 tienen muy pocos datos faltantes, y parecen estar relacionados con algunas variables.

# %%
msno.dendrogram(carreras_24, figsize=(12, 6), fontsize=10)
# Out:
# <Axes: >

# %% [markdown]
# ---
# ## Outliers
# ---

# %% [markdown]
# #### Estudio de outliers en PitTime

# %%
carreras_24 = carreras_24.sort_values(by=['EventName', 'Driver', 'LapNumber'])

# PitIn-Out
carreras_24['PitOutTime2'] = carreras_24.groupby(['EventName', 'Driver'], observed=True)['PitOutTime'].shift(-1)
carreras_24['PitTime'] = carreras_24['PitOutTime2'] - carreras_24['PitInTime']

# Creamos nueva variable 'PitTime_seconds' que guarda el tiempo de parada en boxes
carreras_24['PitTime_seconds'] = carreras_24['PitTime'].dt.total_seconds()

# Creo nueva variable binaria que indica si el piloto hizo una parada en boxes o no. 
carreras_24['Pit'] = np.where(carreras_24['PitTime_seconds'].isna(), False, True)

carreras_24.head()
# Out:
#                   EventName  EventDate Driver DriverNumber      Team  \
# 25580  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25605  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25624  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25643  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25662  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
#
#       PitInTime PitOutTime IsPersonalBest Stint  LapTime  ...  TrackStatus  \
# 25580       NaT        NaT          False   1.0  101.190  ...           12
# 25605       NaT        NaT           True   1.0  120.191  ...           26
# 25624       NaT        NaT           True   1.0   95.776  ...          671
# 25643       NaT        NaT           True   1.0   90.060  ...            1
# 25662       NaT        NaT          False   1.0   90.369  ...            1
#
#        Position Deleted  DeletedReason  FastF1Generated  IsAccurate  \
# 25580        16   False            NaN            False       False
# 25605        15   False            NaN            False       False
# 25624        15   False            NaN            False       False
# 25643        15   False            NaN            False        True
# 25662        15   False            NaN            False        True
#
#        PitOutTime2  PitTime  PitTime_seconds    Pit
# 25580          NaT      NaT              NaN  False
# 25605          NaT      NaT              NaN  False
# 25624          NaT      NaT              NaN  False
# 25643          NaT      NaT              NaN  False
# 25662          NaT      NaT              NaN  False
#
# [5 rows x 36 columns]

# %%
# Verifico que para no nulos en PitTime haya un True en Pit
carreras_24[(carreras_24['PitTime_seconds'].notna())].head(10)
# Out:
#                   EventName  EventDate Driver DriverNumber          Team  \
# 25794  Abu Dhabi Grand Prix 2024-12-08    ALB           23      Williams
# 25807  Abu Dhabi Grand Prix 2024-12-08    ALO           14  Aston Martin
# 26248  Abu Dhabi Grand Prix 2024-12-08    ALO           14  Aston Martin
# 25679  Abu Dhabi Grand Prix 2024-12-08    BOT           77   Kick Sauber
# 25627  Abu Dhabi Grand Prix 2024-12-08    COL           43      Williams
# 25981  Abu Dhabi Grand Prix 2024-12-08    DOO           61        Alpine
# 25821  Abu Dhabi Grand Prix 2024-12-08    GAS           10        Alpine
# 26190  Abu Dhabi Grand Prix 2024-12-08    HAM           44      Mercedes
# 25805  Abu Dhabi Grand Prix 2024-12-08    HUL           27  Haas F1 Team
# 25995  Abu Dhabi Grand Prix 2024-12-08    LAW           30            RB
#
#                    PitInTime PitOutTime IsPersonalBest Stint  LapTime  ...  \
# 25794 0 days 01:15:40.720000        NaT          False   1.0   92.201  ...
# 25807 0 days 01:17:02.713000        NaT          False   1.0   93.244  ...
# 26248 0 days 01:53:23.943000        NaT          False   2.0   91.999  ...
# 25679 0 days 01:06:36.737000        NaT          False   1.0   93.388  ...
# 25627 0 days 01:02:42.334000        NaT          False   1.0  130.710  ...
# 25981 0 days 01:30:55.550000        NaT          False   1.0   93.037  ...
# 25821 0 days 01:18:24.603000        NaT          False   1.0   92.241  ...
# 26190 0 days 01:48:31.010000        NaT          False   1.0   91.792  ...
# 25805 0 days 01:16:58.954000        NaT          False   1.0   92.490  ...
# 25995 0 days 01:32:17.724000        NaT          False   1.0   94.497  ...
#
#        TrackStatus  Position Deleted  DeletedReason  FastF1Generated  \
# 25794            1        14   False            NaN            False
# 25807            1         8   False            NaN            False
# 26248            1         9   False            NaN            False
# 25679            1        16   False            NaN            False
# 25627          671        19   False            NaN            False
# 25981            1        13   False            NaN            False
# 25821            1         4   False            NaN            False
# 26190            1         4   False            NaN            False
# 25805            1         7   False            NaN            False
# 25995            1         9   False            NaN            False
#
#        IsAccurate            PitOutTime2                PitTime  \
# 25794       False 0 days 01:16:02.774000 0 days 00:00:22.054000
# 25807       False 0 days 01:17:26.460000 0 days 00:00:23.747000
# 26248       False 0 days 01:53:46.293000 0 days 00:00:22.350000
# 25679       False 0 days 01:07:17.835000 0 days 00:00:41.098000
# 25627       False 0 days 01:03:07.286000 0 days 00:00:24.952000
# 25981       False 0 days 01:31:17.616000 0 days 00:00:22.066000
# 25821       False 0 days 01:18:46.590000 0 days 00:00:21.987000
# 26190       False 0 days 01:48:52.703000 0 days 00:00:21.693000
# 25805       False 0 days 01:17:20.529000 0 days 00:00:21.575000
# 25995       False 0 days 01:32:41.180000 0 days 00:00:23.456000
#
#        PitTime_seconds   Pit
# 25794           22.054  True
# 25807           23.747  True
# 26248           22.350  True
# 25679           41.098  True
# 25627           24.952  True
# 25981           22.066  True
# 25821           21.987  True
# 26190           21.693  True
# 25805           21.575  True
# 25995           23.456  True
#
# [10 rows x 36 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
sns.boxplot(data=carreras_24[carreras_24['Pit']==True], y='PitTime_seconds', ax=ax[0])
sns.boxplot(data=carreras_24[carreras_24['Pit']==True], y='PitTime_seconds', showfliers= False, ax=ax[1])       
ax[0].grid(axis='y', ls='--')
ax[0].set_title('Boxplot para PitTime_seconds', fontsize=12)
ax[1].grid(axis='y', ls='--')
ax[1].set_title('Boxplot para PitTime_seconds sin mostrar outliers', fontsize=12)

plt.show()

# %%
carreras_24[carreras_24['PitTime_seconds'] > 500][['Driver', 'EventName', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time','LapNumber', 'Pit', 'Deleted', 'Position', 'PitTime_seconds', 'TrackStatus']]
# Out:
#       Driver             EventName   LapTime  Sector1Time  Sector2Time  \
# 3031     ALO   Japanese Grand Prix   140.526          NaN       69.943
# 3040     BOT   Japanese Grand Prix   164.736          NaN       81.589
# 3042     GAS   Japanese Grand Prix   173.223          NaN       85.099
# 3034     HAM   Japanese Grand Prix   152.716          NaN       77.160
# 3045     HUL   Japanese Grand Prix   162.853          NaN       80.740
# 3029     LEC   Japanese Grand Prix   154.543          NaN       77.828
# 3039     MAG   Japanese Grand Prix   185.172          NaN       88.402
# 3030     NOR   Japanese Grand Prix   134.751          NaN       65.666
# 3041     OCO   Japanese Grand Prix   170.167          NaN       84.316
# 3046     PER   Japanese Grand Prix   132.767          NaN       65.032
# 3033     PIA   Japanese Grand Prix   144.356          NaN       72.784
# 3032     RUS   Japanese Grand Prix   159.587          NaN       78.942
# 3036     SAI   Japanese Grand Prix   137.613          NaN       67.997
# 3043     SAR   Japanese Grand Prix   188.456          NaN       89.197
# 3038     STR   Japanese Grand Prix   179.595          NaN       86.629
# 3037     TSU   Japanese Grand Prix   167.566          NaN       83.186
# 3028     VER   Japanese Grand Prix   130.735          NaN       64.045
# 3044     ZHO   Japanese Grand Prix   195.118          NaN       90.308
# 7323     ALB     Monaco Grand Prix  2494.817          NaN       55.498
# 7333     ALO     Monaco Grand Prix  2513.184          NaN       60.893
# 7327     BOT     Monaco Grand Prix  2521.748          NaN       63.149
# 7325     GAS     Monaco Grand Prix  2497.695          NaN       57.790
# 7320     HAM     Monaco Grand Prix  2483.804          NaN       52.196
# 7316     LEC     Monaco Grand Prix  2456.330          NaN       46.389
# 7317     NOR     Monaco Grand Prix  2468.042          NaN       47.606
# 7334     PIA     Monaco Grand Prix  2458.744          NaN       47.944
# 7326     RIC     Monaco Grand Prix  2507.607          NaN       59.863
# 7318     RUS     Monaco Grand Prix  2473.884          NaN       49.669
# 7324     SAI     Monaco Grand Prix  2462.721          NaN       58.173
# 7329     SAR     Monaco Grand Prix  2516.858          NaN       61.643
# 7328     STR     Monaco Grand Prix  2502.648          NaN       59.540
# 7321     TSU     Monaco Grand Prix  2488.609          NaN       54.783
# 7319     VER     Monaco Grand Prix  2478.944          NaN       50.381
# 7330     ZHO     Monaco Grand Prix  2526.253          NaN       49.767
# 23120    ALO  São Paulo Grand Prix       NaN       32.000       66.314
# 23126    BEA  São Paulo Grand Prix       NaN       31.026       63.759
# 23123    BOT  São Paulo Grand Prix       NaN       29.529       66.595
# 23113    GAS  São Paulo Grand Prix       NaN       35.541       69.588
# 23122    HAM  São Paulo Grand Prix       NaN       32.651       65.042
# 23121    LAW  São Paulo Grand Prix       NaN       31.300       66.115
# 23117    LEC  São Paulo Grand Prix       NaN       35.820       68.640
# 23114    NOR  São Paulo Grand Prix       NaN       34.575       69.295
# 23110    OCO  São Paulo Grand Prix       NaN       36.080       72.164
# 23125    PER  São Paulo Grand Prix       NaN       32.169       63.536
# 23118    PIA  São Paulo Grand Prix       NaN       35.297       67.831
# 23115    RUS  São Paulo Grand Prix       NaN       36.103       68.737
# 23124    SAI  São Paulo Grand Prix       NaN       31.081       64.584
# 23116    TSU  São Paulo Grand Prix       NaN       36.143       69.173
# 23111    VER  São Paulo Grand Prix       NaN       35.920       71.429
# 23112    ZHO  São Paulo Grand Prix       NaN       36.416       70.767
#
#        Sector3Time  LapNumber   Pit Deleted Position  PitTime_seconds  \
# 3031        32.569          1  True   False        7         1580.927
# 3040        43.219          1  True   False       13         1582.254
# 3042        47.334          1  True   False       16         1586.631
# 3034        37.060          1  True   False        9         1580.802
# 3045        42.423          1  True   False       12         1580.818
# 3029        37.701          1  True   False       10         1583.228
# 3039        55.147          1  True   False       18         1584.324
# 3030        32.333          1  True   False        5         1580.107
# 3041        45.396          1  True   False       15         1585.943
# 3046        31.841          1  True   False        4         1577.565
# 3033        33.312          1  True   False        8         1580.237
# 3032        41.309          1  True   False       11         1581.202
# 3036        32.076          1  True   False        6         1580.111
# 3043        57.246          1  True   False       19         1584.630
# 3038        51.822          1  True   False       17         1585.480
# 3037        44.247          1  True   False       14         1584.064
# 3028        31.458          1  True   False        1         1575.473
# 3044        62.545          1  True   False       20         1582.308
# 7323           NaN          1  True   False       13         2381.054
# 7333           NaN          1  True   False       17         2389.249
# 7327           NaN          1  True   False       19         2393.833
# 7325           NaN          1  True   False       14         2381.591
# 7320           NaN          1  True   False       11         2375.143
# 7316           NaN          1  True   False        1         2357.749
# 7317           NaN          1  True   False        8         2365.334
# 7334           NaN          1  True   False        6         2357.441
# 7326           NaN          1  True   False       16         2385.475
# 7318           NaN          1  True   False        9         2369.483
# 7324           NaN          1  True   False        7         2326.813
# 7329           NaN          1  True   False       18         2391.428
# 7328           NaN          1  True   False       15         2383.368
# 7321           NaN          1  True   False       12         2377.337
# 7319           NaN          1  True   False       10         2372.479
# 7330           NaN          1  True   False       20         2386.517
# 23120       62.776         32  True   False        9         1422.914
# 23126       64.005         32  True   False       15         1424.776
# 23123       55.723         32  True   False       12         1422.111
# 23113       55.679         32  True   False        3         1407.544
# 23122       63.289         32  True   False       11         1425.721
# 23121       61.374         32  True   False       10         1422.640
# 23117       59.265         32  True   False        7         1420.292
# 23114       56.062         32  True   False        4         1415.364
# 23110       49.986         32  True   False        1         1408.728
# 23125       61.073         32  True   False       14         1425.246
# 23118       61.396         32  True   False        8         1420.139
# 23115       58.052         32  True   False        5         1415.867
# 23124       58.543         32  True   False       13         1424.621
# 23116       57.768         32  True   False        6         1419.015
# 23111       51.280         32  True   False        2         1409.224
# 23112       53.337         31  True   False       16         1283.040
#
#       TrackStatus
# 3031          125
# 3040          125
# 3042          125
# 3034          125
# 3045          125
# 3029          125
# 3039          125
# 3030          125
# 3041          125
# 3046          125
# 3033          125
# 3032          125
# 3036          125
# 3043          125
# 3038          125
# 3037          125
# 3028          125
# 3044          125
# 7323         1254
# 7333         1254
# 7327         1254
# 7325         1254
# 7320         1254
# 7316         1254
# 7317         1254
# 7334         1254
# 7326         1254
# 7318         1254
# 7324         1254
# 7329         1254
# 7328         1254
# 7321         1254
# 7319         1254
# 7330         1254
# 23120          45
# 23126          45
# 23123          45
# 23113          45
# 23122          45
# 23121          45
# 23117          45
# 23114          45
# 23110          45
# 23125          45
# 23118          45
# 23115          45
# 23124          45
# 23116          45
# 23111          45
# 23112          45

# %% [markdown]
# Obs:
# * En la pista de Suzuka chocaron Ricciardo y Albon al comienzo en la vuelta 1 y hubo Red Flag.
# * En Mónaco hubo Red Flag por choque en la vuelta 1 después de un choque entre Pérez, Hülkenberg y Magnussen.
# * En Sao Paulo hubo Red Flag por el choque de Colapinto en la vuelta 32.

# %% [markdown]
# #### ¿Podemos asumir que son legítimos?

# %% [markdown]
# ---
# #### Exporto el dataset con los cambios de dtype (queda disponible para leer en otra notebook)
# ---

# %%
import json

# Detectar columnas categóricas
categorical_cols = [col for col, dtype in carreras_24.dtypes.items() if str(dtype) == 'category']

# Guardar los tipos como strings
dtypes_str = {col: str(dtype) for col, dtype in carreras_24.dtypes.items()}

# Guardar todo en un solo JSON
info = {
    "dtypes": dtypes_str,
    "categoricals": categorical_cols
}

with open("../datasets/carreras_24_1_dtypes.json", "w") as f:
    json.dump(info, f)

# exportar CSV
carreras_24.to_csv('../datasets/carreras_24_1.csv', index=False)
