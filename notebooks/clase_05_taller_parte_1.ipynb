# %% [markdown]
# ## Análisis de datos - Clase 6

# %% [markdown]
# # Taller práctico - análisis de un dataset

# %% [markdown]
# En esta clase vamos a analizar en forma completa un dataset con datos de Fórmula 1 de la temporada 2024 (los datos fueron extraídos con la biblioteca Fastf1). El dataset contiene información sobre las carreras, los pilotos, los tiempos y los resultados de cada evento.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Dataset de carreras del 2024
raw_carreras_24 = pd.read_csv('../datasets/f1_2024_R.csv')

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Columnas y tipos de datos

# %%
raw_carreras_24.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'EventName', 'SessionType',
#        'EventDate', 'Time_weather', 'AirTemp', 'TrackTemp', 'Humidity',
#        'AvgSpeed', 'MaxThrottle', 'AvgBrake'],
#       dtype='object')

# %%
# Armamos un nuevo dataset con menos columnas para el análisis
carreras_24 = raw_carreras_24.drop(columns=['Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
        'SessionType', 'AvgSpeed', 'MaxThrottle', 'AvgBrake', 'Time_weather'], axis=1)

# %%
carreras_24.shape
# Out:
# (26606, 32)

# %%
carreras_24.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'SpeedI1',
#        'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest', 'Compound',
#        'TyreLife', 'FreshTyre', 'Team', 'LapStartTime', 'LapStartDate',
#        'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'EventName', 'EventDate', 'AirTemp',
#        'TrackTemp', 'Humidity'],
#       dtype='object')

# %% [markdown]
# ### Detalles de las columnas del dataset
#
# #### Evento
# * EventName
# * EventDate
#
# #### Corredor y equipo
# * Driver: nombre del piloto
# * DriverNumber: número del piloto
# * Team: nombre del equipo constructor
# * Grid: posición de salida (1,2,3, etc.) ### ????
#
# #### Vueltas y tiempos
# * PitInLap: tiempo desde el comienzo de la vuelta en el que el piloto entra en boxes (timedelta).
# * PitOutLap: tiempo desde el comienzo de la vuelta en el que el piloto sale de boxes (timedelta).
# * IsPersonalBest: indica si la vuelta fue la mejor del piloto en la sesión (1,0)
# * Stint: indica el cambio de cubiertas (1,2,3, etc.)
# * LapTime: tiempo de la vuelta (en segundos)
# * LapNumber: número de vuelta (1,2,3, etc.)
# * LapStartTime
# * LapStartDate
# * Sector1Time
# * Sector2Time
# * Sector3Time
#
# #### Telemetría
#
# * SpeedI1, SpeedI2: velocidad en dos puntos intermedio de la vuelta (km/h)
# * SpeedFL: velocidad en la línea de meta (km/h)
# * SpeedST: velocidad en el speed trap que es el punto más rápido en la recta (km/h)
#
# #### Condiciones climáticas
# * AirTemp: temperatura del aire (°C)
# * TrackTemp: temperatura de la pista (°C)
# * Humidity: humedad (%)
#
# #### Cubiertas
# * Compound: tipo de cubierta (Duro, Medio, Blando, de lluvia, etc.)
# * TyreLife: vida útil de la cubierta (número de vueltas)
# * FreshTyre: indica si la cubierta es nueva o usada (1,0)
#
# #### Contexto
#
# * TrackStatus: las condiciones de la pista (1 para verde, 2 para amarilla, 4 para Safety Car)
# * Position: la posición del piloto al final de la vuelta (1,2,3, etc.)
# * Deleted: indica si la vuelta fue eliminada (por alguna infracción, por ejemplo, por exceder los límites de la pista)
# * DeletedReason: la razon por la que la vuelta fue eliminada (por ejemplo, por exceder los límites de la pista)
# * FastF1Generated: indica si los datos fueron generados por FastF1 (por ejemplo, si la telemetría está incompleta)
# * IsAccurate: indica si los datos son confiables (por ejemplo, si no hay interpolación)

# %%
# Reordeno las columnas para poder identificarlas y analizarlas más cómodamente 
nuevo_orden = ['EventName', 'EventDate',                           # Evento
               'Driver', 'DriverNumber', 'Team',                   # Corredor y equipo               
               'PitInTime', 'PitOutTime', 'IsPersonalBest',        # Vueltas y tiempos
               'Stint', 'LapTime', 'LapNumber',
               'LapStartTime', 'LapStartDate',
               'Sector1Time', 'Sector2Time', 'Sector3Time',
               'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST',         # Telemetría
               'AirTemp', 'TrackTemp', 'Humidity',                 # Condiciones climáticas
               'Compound', 'TyreLife', 'FreshTyre',                # Cubiertas

               'TrackStatus', 'Position',                          # Contexto
               'Deleted', 'DeletedReason',
               'FastF1Generated', 'IsAccurate'
]
carreras_24 = carreras_24[nuevo_orden]

# %% [markdown]
# ### Vista general del dataset

# %%
carreras_24.head(10)
# Out:
#             EventName   EventDate Driver  DriverNumber             Team  \
# 0  Bahrain Grand Prix  2024-03-02    VER             1  Red Bull Racing
# 1  Bahrain Grand Prix  2024-03-02    LEC            16          Ferrari
# 2  Bahrain Grand Prix  2024-03-02    RUS            63         Mercedes
# 3  Bahrain Grand Prix  2024-03-02    NOR             4          McLaren
# 4  Bahrain Grand Prix  2024-03-02    HAM            44         Mercedes
# 5  Bahrain Grand Prix  2024-03-02    PIA            81          McLaren
# 6  Bahrain Grand Prix  2024-03-02    ALO            14     Aston Martin
# 7  Bahrain Grand Prix  2024-03-02    SAR             2         Williams
# 8  Bahrain Grand Prix  2024-03-02    SAI            55          Ferrari
# 9  Bahrain Grand Prix  2024-03-02    ZHO            24      Kick Sauber
#
#   PitInTime PitOutTime IsPersonalBest  Stint  LapTime  ...  Humidity  \
# 0       NaN        NaN          False    1.0   97.284  ...      49.0
# 1       NaN        NaN          False    1.0   98.271  ...      49.0
# 2       NaN        NaN          False    1.0   99.228  ...      49.0
# 3       NaN        NaN          False    1.0  102.168  ...      49.0
# 4       NaN        NaN          False    1.0  103.122  ...      49.0
# 5       NaN        NaN          False    1.0  102.523  ...      49.0
# 6       NaN        NaN          False    1.0  101.679  ...      49.0
# 7       NaN        NaN          False    1.0  105.921  ...      49.0
# 8       NaN        NaN          False    1.0  100.620  ...      49.0
# 9       NaN        NaN          False    1.0  104.801  ...      49.0
#
#    Compound TyreLife  FreshTyre  TrackStatus  Position  Deleted  \
# 0      SOFT      4.0      False           12       1.0    False
# 1      SOFT      4.0      False           12       2.0    False
# 2      SOFT      4.0      False           12       3.0    False
# 3      SOFT      4.0      False           12       7.0    False
# 4      SOFT      4.0      False           12       9.0    False
# 5      SOFT      4.0      False           12       8.0    False
# 6      SOFT      4.0      False           12       6.0    False
# 7      SOFT      1.0       True           12      15.0    False
# 8      SOFT      4.0      False           12       5.0    False
# 9      SOFT      1.0       True           12      13.0    False
#
#    DeletedReason  FastF1Generated  IsAccurate
# 0            NaN            False       False
# 1            NaN            False       False
# 2            NaN            False       False
# 3            NaN            False       False
# 4            NaN            False       False
# 5            NaN            False       False
# 6            NaN            False       False
# 7            NaN            False       False
# 8            NaN            False       False
# 9            NaN            False       False
#
# [10 rows x 32 columns]

# %%
carreras_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26606 entries, 0 to 26605
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EventName        26606 non-null  object
#  1   EventDate        26606 non-null  object
#  2   Driver           26606 non-null  object
#  3   DriverNumber     26606 non-null  int64
#  4   Team             26606 non-null  object
#  5   PitInTime        849 non-null    object
#  6   PitOutTime       840 non-null    object
#  7   IsPersonalBest   26591 non-null  object
#  8   Stint            26606 non-null  float64
#  9   LapTime          26381 non-null  float64
#  10  LapNumber        26606 non-null  float64
#  11  LapStartTime     26606 non-null  float64
#  12  LapStartDate     26591 non-null  object
#  13  Sector1Time      26066 non-null  float64
#  14  Sector2Time      26574 non-null  float64
#  15  Sector3Time      26553 non-null  float64
#  16  SpeedI1          22460 non-null  float64
#  17  SpeedI2          26552 non-null  float64
#  18  SpeedFL          25728 non-null  float64
#  19  SpeedST          24422 non-null  float64
#  20  AirTemp          26606 non-null  float64
#  21  TrackTemp        26606 non-null  float64
#  22  Humidity         26606 non-null  float64
#  23  Compound         26606 non-null  object
#  24  TyreLife         26606 non-null  float64
#  25  FreshTyre        26606 non-null  bool
#  26  TrackStatus      26606 non-null  int64
#  27  Position         26578 non-null  float64
#  28  Deleted          26606 non-null  bool
#  29  DeletedReason    326 non-null    object
#  30  FastF1Generated  26606 non-null  bool
#  31  IsAccurate       26606 non-null  bool
# dtypes: bool(4), float64(16), int64(2), object(10)
# memory usage: 5.8+ MB

# %% [markdown]
# ### Ajustamos los tipos de datos

# %%
# Categóricas
carreras_24['EventName'] = carreras_24['EventName'].astype('category')
carreras_24['Driver'] = carreras_24['Driver'].astype('category')
carreras_24['DriverNumber'] = carreras_24['DriverNumber'].astype('category')
carreras_24['Team'] = carreras_24['Team'].astype('category')
carreras_24['FreshTyre'] = carreras_24['FreshTyre'].astype('category')
carreras_24['TyreLife'] = carreras_24['TyreLife'].astype('category')
carreras_24['Compound'] = carreras_24['Compound'].astype('category')
carreras_24['Stint'] = carreras_24['Stint'].astype('category')
carreras_24['IsPersonalBest'] = carreras_24['IsPersonalBest'].astype('category')
carreras_24['Deleted'] = carreras_24['Deleted'].astype('category')
carreras_24['DeletedReason'] = carreras_24['DeletedReason'].astype('category')
carreras_24['TrackStatus'] = carreras_24['TrackStatus'].astype('category')

# Numéricas temporales
carreras_24['EventDate'] = pd.to_datetime(carreras_24['EventDate'])
carreras_24['PitInTime'] = pd.to_timedelta(carreras_24['PitInTime'])
carreras_24['PitOutTime'] = pd.to_timedelta(carreras_24['PitOutTime'])

# Numéricas discretas
carreras_24['LapNumber'] = carreras_24['LapNumber'].astype('int')

# %% [markdown]
# ---

# %% [markdown]
# ### Variables categóricas: exploración

# %%
carreras_24.describe(include='category')
# Out:
#                EventName Driver  DriverNumber     Team IsPersonalBest  \
# count              26606  26606         26606    26606          26591
# unique                24     24            25       10              2
# top     Dutch Grand Prix    PIA            81  McLaren          False
# freq                1426   1444          1444     2881          21094
#
#           Stint Compound  TyreLife FreshTyre  TrackStatus Deleted  \
# count   26606.0    26606   26606.0     26606        26606   26606
# unique      5.0        6      78.0         2           25       2
# top         2.0     HARD       4.0      True            1   False
# freq    11438.0    13767    1162.0     21042        24604   26280
#
#                          DeletedReason
# count                              326
# unique                             255
# top     TRACK LIMITS AT TURN 1 LAP 10
# freq                                 5

# %% [markdown]
# #### Evento

# %%
# Grand Prix que se corrieron en el 2024
carreras_24['EventName'].unique()
# Out:
# ['Bahrain Grand Prix', 'Saudi Arabian Grand Prix', 'Australian Grand Prix', 'Japanese Grand Prix', 'Chinese Grand Prix', ..., 'Mexico City Grand Prix', 'São Paulo Grand Prix', 'Las Vegas Grand Prix', 'Qatar Grand Prix', 'Abu Dhabi Grand Prix']
# Length: 24
# Categories (24, object): ['Abu Dhabi Grand Prix', 'Australian Grand Prix', 'Austrian Grand Prix', 'Azerbaijan Grand Prix', ..., 'Singapore Grand Prix', 'Spanish Grand Prix', 'São Paulo Grand Prix', 'United States Grand Prix']

# %% [markdown]
# #### Corredor y equipo

# %%
# Pilotos que corrieron en el 2024
carreras_24['Driver'].unique()
# Out:
# ['VER', 'LEC', 'RUS', 'NOR', 'HAM', ..., 'STR', 'BEA', 'COL', 'LAW', 'DOO']
# Length: 24
# Categories (24, object): ['ALB', 'ALO', 'BEA', 'BOT', ..., 'STR', 'TSU', 'VER', 'ZHO']

# %%
# Equipos
carreras_24['Team'].unique()
# Out:
# ['Red Bull Racing', 'Ferrari', 'Mercedes', 'McLaren', 'Aston Martin', 'Williams', 'Kick Sauber', 'RB', 'Haas F1 Team', 'Alpine']
# Categories (10, object): ['Alpine', 'Aston Martin', 'Ferrari', 'Haas F1 Team', ..., 'Mercedes', 'RB', 'Red Bull Racing', 'Williams']

# %% [markdown]
# #### Cubiertas

# %%
carreras_24['Compound'].unique()
# Out:
# ['SOFT', 'HARD', 'MEDIUM', 'INTERMEDIATE', 'WET', 'UNKNOWN']
# Categories (6, object): ['HARD', 'INTERMEDIATE', 'MEDIUM', 'SOFT', 'UNKNOWN', 'WET']

# %%
carreras_24['TyreLife'].unique()
# Out:
# [4.0, 1.0, 5.0, 2.0, 6.0, ..., 74.0, 75.0, 76.0, 77.0, 78.0]
# Length: 78
# Categories (78, float64): [1.0, 2.0, 3.0, 4.0, ..., 75.0, 76.0, 77.0, 78.0]

# %% [markdown]
# #### Contexto

# %% [markdown]
# **Variable TrackStatus**
#
# Valores conocidos (https://docs.fastf1.dev/api.html#fastf1.api.track_status_data)
#
# * 1: Track clear (beginning of session or to indicate the end of another status)
# * 2: Yellow flag (sectors are unknown)
# * 3: ??? Never seen so far, does not exist?
# * 4: Safety Car
# * 5: Red Flag
# * 6: Virtual Safety Car deployed
# * 7: Virtual Safety Car ending (As indicated on the drivers steering wheel, on tv and so on; status ‘1’ will mark the actual end)

# %%
carreras_24['TrackStatus'].unique()
# Out:
# [12, 1, 21, 124, 24, ..., 412, 267, 45, 51, 1264]
# Length: 25
# Categories (25, int64): [1, 4, 6, 12, ..., 1254, 1264, 1267, 2671]

# %%
sns.set_theme(font_scale=0.6)
sns.countplot(data=carreras_24, x= 'TrackStatus', stat='percent' )
# Out:
# <Axes: xlabel='TrackStatus', ylabel='percent'>

# %% [markdown]
# ---
# ### Variables numéricas: estadística descriptiva

# %%
carreras_24.describe()
# Out:
#                            EventDate                  PitInTime  \
# count                          26606                        849
# mean   2024-07-20 19:42:45.165752064  0 days 01:36:26.654181389
# min              2024-03-02 00:00:00     0 days 00:15:20.353000
# 25%              2024-05-19 00:00:00     0 days 01:16:58.954000
# 50%              2024-07-07 00:00:00     0 days 01:38:45.781000
# 75%              2024-09-22 00:00:00     0 days 01:53:19.090000
# max              2024-12-08 00:00:00     0 days 03:10:59.688000
# std                              NaN  0 days 00:24:02.916710214
#
#                       PitOutTime       LapTime     LapNumber  LapStartTime  \
# count                        840  26381.000000  26606.000000  26606.000000
# mean   0 days 01:37:42.147103571     92.727333     30.507931   6191.722126
# min       0 days 00:04:17.809000     67.694000      1.000000    245.608000
# 25%       0 days 01:18:31.260750     81.964000     15.000000   4707.357750
# 50%       0 days 01:38:21.220500     89.076000     30.000000   6136.312500
# 75%       0 days 01:53:11.494750     98.704000     45.000000   7584.237750
# max       0 days 03:11:24.136000   2526.253000     78.000000  11925.420000
# std       0 days 00:24:21.070185     60.498621     18.260169   1929.832188
#
#         Sector1Time   Sector2Time   Sector3Time       SpeedI1       SpeedI2  \
# count  26066.000000  26574.000000  26553.000000  22460.000000  26552.000000
# mean      28.544514     35.105664     27.942290    254.994167    247.649292
# min       16.897000     17.488000     17.690000     59.000000     57.000000
# 25%       25.398250     29.584000     23.076000    214.000000    211.000000
# 50%       28.470000     32.958000     25.949000    273.000000    257.000000
# 75%       31.086000     41.288000     31.986000    289.000000    280.000000
# max       97.585000     90.308000     97.241000    357.000000    343.000000
# std        6.928019      7.506386      7.434872     45.269851     43.887292
#
#             SpeedFL       SpeedST       AirTemp     TrackTemp      Humidity  \
# count  25728.000000  24422.000000  26606.000000  26606.000000  26606.000000
# mean     268.093711    296.643928     23.490434     35.588191     54.358303
# min        1.000000     64.000000     14.500000     16.700000     30.000000
# 25%      248.000000    289.000000     19.200000     28.700000     45.000000
# 50%      275.000000    302.000000     22.000000     37.000000     53.000000
# 75%      291.000000    313.000000     28.300000     43.500000     63.000000
# max      357.000000    362.000000     33.900000     51.700000     92.000000
# std       34.744874     31.732479      4.789366      9.032689     13.877374
#
#            Position
# count  26578.000000
# mean       9.793325
# min        1.000000
# 25%        5.000000
# 50%       10.000000
# 75%       14.000000
# max       20.000000
# std        5.430816

# %% [markdown]
# #### Tiempos

# %%
fig, ax = plt.subplots(3, 1,figsize=(20, 18))

sns.boxplot(data=carreras_24, y='Sector1Time', x='Driver', ax=ax[0])
sns.boxplot(data=carreras_24, y='Sector2Time', x='Driver', ax=ax[1])
sns.boxplot(data=carreras_24, y='Sector3Time', x='Driver', ax=ax[2])

for i in (0,1,2):
    ax[i].grid(axis='y', ls='--')
    ax[i].set_title(f'Sector {i+1}')

plt.show()

# %%
def scatter(driver, race='all'):
    if race == 'all':
        df = carreras_24[carreras_24['Driver']==driver]
    else:
        df = carreras_24[(carreras_24['Driver']==driver) & (carreras_24['EventName']==race)]

    plt.figure(figsize=(10, 5))
    plt.scatter(df['LapStartDate'], df['Sector1Time'], label='Sector 1', alpha=0.7)
    plt.scatter(df['LapStartDate'], df['Sector2Time'], label='Sector 2', alpha=0.7)
    plt.scatter(df['LapStartDate'], df['Sector3Time'], label='Sector 3', alpha=0.7)

    plt.xlabel('')
    plt.ylabel('Time')
    plt.title(f'Tiempos por sector - Piloto: {driver} - Carrera(s):{race}')
    plt.legend()
    plt.xticks(ticks=plt.xticks()[0], labels=[''] * len(plt.xticks()[0]))
    plt.show()

# %%
scatter('NOR', 'Australian Grand Prix')

# %% [markdown]
# ---
# ## Datos faltantes

# %%
# Serie con los valores faltantes
faltantes = carreras_24.isnull().sum()

# Calculamos porcentaje de valores faltantes
total_filas = len(carreras_24)
faltantes_df = faltantes.to_frame(name='faltantes')
faltantes_df['porcentaje'] = ((faltantes_df['faltantes'] / total_filas) * 100).round(2)
faltantes_df = faltantes_df.sort_values(by='faltantes', ascending=False)

# Mostramos solo las que tienen valores faltantes
faltantes_df[faltantes_df['faltantes'] > 0]
# Out:
#                 faltantes  porcentaje
# DeletedReason       26280       98.77
# PitOutTime          25766       96.84
# PitInTime           25757       96.81
# SpeedI1              4146       15.58
# SpeedST              2184        8.21
# SpeedFL               878        3.30
# Sector1Time           540        2.03
# LapTime               225        0.85
# SpeedI2                54        0.20
# Sector3Time            53        0.20
# Sector2Time            32        0.12
# Position               28        0.11
# IsPersonalBest         15        0.06
# LapStartDate           15        0.06

# %% [markdown]
# #### Análisis de nulos de PitInTime y PitOutTime

# %% [markdown]
# Los pilotos están obligados a hacer al menos 1 parada en boxes por carrera. Los datos de PitInTime y PitOutTime son nulos para las vueltas que no tienen parada en boxes. Esto es esperable por diseño (no son realmente faltantes)
#
# ¿Qué hacemos en este caso?
# - Opción 1: reemplazar con 0s los nulos. Problema: son columnas que indican tiempos!
# - Opción 2: crear 2 nuevas columnas: Boxes (True/False) y PitTime (PitInTime - PitOutTime). PitTime tendrá valores 0 para aquellas vueltas que no tienen parada en boxes.

# %%
# Cantidad de filas que no tienen nulos
PitInTime_no_nulos = total_filas-faltantes['PitInTime']
PitOutTime_no_nulos = total_filas-faltantes['PitOutTime']

print(f'Cantidad de entradas a boxes: {PitInTime_no_nulos}, cantidad de salidas de boxes: {PitOutTime_no_nulos}')
# Out:
# Cantidad de entradas a boxes: 849, cantidad de salidas de boxes: 840

# %%
carreras_24[(carreras_24['PitInTime'].notnull()) & (carreras_24['PitOutTime'].notnull())]
# Out:
#                        EventName  EventDate Driver DriverNumber  \
# 3245         Japanese Grand Prix 2024-04-07    ZHO           24
# 6252   Emilia Romagna Grand Prix 2024-05-19    ALB           23
# 23058       São Paulo Grand Prix 2024-11-03    ZHO           24
# 23119       São Paulo Grand Prix 2024-11-03    HUL           27
# 23127       São Paulo Grand Prix 2024-11-03    ZHO           24
# 23915       Las Vegas Grand Prix 2024-11-23    OCO           31
# 24773           Qatar Grand Prix 2024-12-01    STR           18
# 25230           Qatar Grand Prix 2024-12-01    HAM           44
# 25231           Qatar Grand Prix 2024-12-01    VER            1
# 25232           Qatar Grand Prix 2024-12-01    NOR            4
# 25234           Qatar Grand Prix 2024-12-01    LEC           16
# 25236           Qatar Grand Prix 2024-12-01    PER           11
# 25238           Qatar Grand Prix 2024-12-01    GAS           10
# 25239           Qatar Grand Prix 2024-12-01    RUS           63
# 25240           Qatar Grand Prix 2024-12-01    ALO           14
# 25241           Qatar Grand Prix 2024-12-01    ZHO           24
# 25243           Qatar Grand Prix 2024-12-01    TSU           22
# 25244           Qatar Grand Prix 2024-12-01    ALB           23
# 25246           Qatar Grand Prix 2024-12-01    LAW           30
# 25248           Qatar Grand Prix 2024-12-01    VER            1
# 25249           Qatar Grand Prix 2024-12-01    HAM           44
# 25250           Qatar Grand Prix 2024-12-01    BOT           77
# 25251           Qatar Grand Prix 2024-12-01    NOR            4
# 25252           Qatar Grand Prix 2024-12-01    LEC           16
# 25253           Qatar Grand Prix 2024-12-01    PIA           81
# 25254           Qatar Grand Prix 2024-12-01    PER           11
# 25255           Qatar Grand Prix 2024-12-01    GAS           10
# 25256           Qatar Grand Prix 2024-12-01    RUS           63
# 25257           Qatar Grand Prix 2024-12-01    SAI           55
# 25258           Qatar Grand Prix 2024-12-01    ALO           14
# 25259           Qatar Grand Prix 2024-12-01    ZHO           24
# 25260           Qatar Grand Prix 2024-12-01    MAG           20
# 25261           Qatar Grand Prix 2024-12-01    TSU           22
# 25262           Qatar Grand Prix 2024-12-01    ALB           23
# 25263           Qatar Grand Prix 2024-12-01    HUL           27
# 25264           Qatar Grand Prix 2024-12-01    LAW           30
# 26017       Abu Dhabi Grand Prix 2024-12-08    LAW           30
# 26132       Abu Dhabi Grand Prix 2024-12-08    MAG           20
#
#                   Team              PitInTime             PitOutTime  \
# 3245       Kick Sauber 0 days 01:52:08.494000 0 days 01:50:27.076000
# 6252          Williams 0 days 01:09:28.708000 0 days 01:07:15.914000
# 23058      Kick Sauber 0 days 01:53:35.972000 0 days 01:51:55.386000
# 23119     Haas F1 Team 0 days 02:01:05.310000 0 days 01:58:44.080000
# 23127      Kick Sauber 0 days 02:23:53.295000 0 days 02:22:03.366000
# 23915           Alpine 0 days 01:16:55.566000 0 days 01:15:16.298000
# 24773     Aston Martin 0 days 01:10:57.663000 0 days 01:09:18.818000
# 25230         Mercedes 0 days 01:50:51.672000 0 days 01:48:31.837000
# 25231  Red Bull Racing 0 days 01:50:50.228000 0 days 01:48:29.321000
# 25232          McLaren 0 days 01:50:54.535000 0 days 01:48:33.018000
# 25234          Ferrari 0 days 01:50:57.554000 0 days 01:48:49.395000
# 25236  Red Bull Racing 0 days 01:51:10.874000 0 days 01:49:15.391000
# 25238           Alpine 0 days 01:51:30.152000 0 days 01:49:36.808000
# 25239         Mercedes 0 days 01:51:39.334000 0 days 01:49:45.023000
# 25240     Aston Martin 0 days 01:51:44.862000 0 days 01:49:47.180000
# 25241      Kick Sauber 0 days 01:51:46.695000 0 days 01:49:50.432000
# 25243               RB 0 days 01:52:04.342000 0 days 01:50:10.140000
# 25244         Williams 0 days 01:52:06.082000 0 days 01:50:12.541000
# 25246               RB 0 days 01:52:25.437000 0 days 01:50:31.009000
# 25248  Red Bull Racing 0 days 01:53:38.787000 0 days 01:51:14.174000
# 25249         Mercedes 0 days 01:53:40.728000 0 days 01:51:15.301000
# 25250      Kick Sauber 0 days 01:53:43.053000 0 days 01:51:22.081000
# 25251          McLaren 0 days 01:53:41.289000 0 days 01:51:20.116000
# 25252          Ferrari 0 days 01:53:44.238000 0 days 01:51:23.216000
# 25253          McLaren 0 days 01:53:46.174000 0 days 01:51:24.232000
# 25254  Red Bull Racing 0 days 01:53:48.007000 0 days 01:51:33.680000
# 25255           Alpine 0 days 01:53:50.472000 0 days 01:51:52.820000
# 25256         Mercedes 0 days 01:53:51.621000 0 days 01:52:02.059000
# 25257          Ferrari 0 days 01:53:53.002000 0 days 01:52:04.570000
# 25258     Aston Martin 0 days 01:53:59.448000 0 days 01:52:13.401000
# 25259      Kick Sauber 0 days 01:53:54.687000 0 days 01:52:09.972000
# 25260     Haas F1 Team 0 days 01:53:59.843000 0 days 01:52:13.496000
# 25261               RB 0 days 01:54:02.304000 0 days 01:52:27.163000
# 25262         Williams 0 days 01:54:03.427000 0 days 01:52:28.715000
# 25263     Haas F1 Team 0 days 01:54:05.578000 0 days 01:52:31.352000
# 25264               RB 0 days 01:54:21.128000 0 days 01:52:48.202000
# 26017               RB 0 days 01:34:14.232000 0 days 01:32:41.180000
# 26132     Haas F1 Team 0 days 01:43:34.109000 0 days 01:41:53.698000
#
#       IsPersonalBest Stint  LapTime  ...  Humidity      Compound TyreLife  \
# 3245           False   4.0  128.193  ...      40.0          HARD      5.0
# 6252           False   2.0      NaN  ...      51.0          HARD      1.0
# 23058          False   2.0  126.376  ...      86.0  INTERMEDIATE      1.0
# 23119          False   4.0      NaN  ...      89.0  INTERMEDIATE      1.0
# 23127          False   4.0      NaN  ...      90.0  INTERMEDIATE      1.0
# 23915          False   2.0  114.887  ...      51.0        MEDIUM     12.0
# 24773          False   3.0  140.862  ...      54.0          HARD      1.0
# 25230          False   2.0      NaN  ...      57.0          HARD      1.0
# 25231          False   2.0      NaN  ...      57.0          HARD      1.0
# 25232          False   2.0      NaN  ...      57.0          HARD      1.0
# 25234          False   2.0      NaN  ...      57.0          HARD      1.0
# 25236          False   2.0  143.642  ...      58.0          HARD      1.0
# 25238          False   2.0  142.160  ...      58.0          HARD      1.0
# 25239          False   3.0  142.188  ...      58.0          HARD      1.0
# 25240          False   2.0  146.362  ...      58.0          HARD      1.0
# 25241          False   2.0  146.390  ...      58.0          HARD      1.0
# 25243          False   2.0  143.242  ...      58.0          HARD      1.0
# 25244          False   2.0  142.739  ...      58.0          SOFT      1.0
# 25246          False   2.0      NaN  ...      58.0          HARD      1.0
# 25248          False   3.0      NaN  ...      58.0          HARD      2.0
# 25249          False   3.0      NaN  ...      58.0          HARD      2.0
# 25250          False   3.0      NaN  ...      58.0        MEDIUM      9.0
# 25251          False   3.0      NaN  ...      58.0          HARD      2.0
# 25252          False   3.0      NaN  ...      58.0          HARD      2.0
# 25253          False   3.0      NaN  ...      58.0          HARD      3.0
# 25254          False   3.0      NaN  ...      58.0          HARD      2.0
# 25255          False   3.0  141.304  ...      59.0          HARD      2.0
# 25256          False   4.0  134.784  ...      59.0          HARD      2.0
# 25257          False   3.0  133.402  ...      59.0          HARD      3.0
# 25258          False   3.0  135.542  ...      59.0        MEDIUM      7.0
# 25259          False   3.0  129.664  ...      59.0          HARD      2.0
# 25260          False   3.0  130.074  ...      59.0          HARD     10.0
# 25261          False   3.0  118.996  ...      59.0          HARD      2.0
# 25262          False   3.0  118.603  ...      59.0          SOFT      2.0
# 25263          False   4.0  119.627  ...      59.0        MEDIUM      6.0
# 25264          False   3.0  115.739  ...      59.0          HARD      2.0
# 26017          False   2.0  116.467  ...      53.0          HARD      1.0
# 26132          False   3.0  121.980  ...      56.0          HARD      1.0
#
#        FreshTyre  TrackStatus  Position  Deleted  \
# 3245       False            1      18.0    False
# 6252        True            1      20.0    False
# 23058       True          671      17.0    False
# 23119       True           45      18.0    False
# 23127       True           51      16.0    False
# 23915      False            1      15.0    False
# 24773       True            1      18.0    False
# 25230      False            4      16.0    False
# 25231       True            4       1.0    False
# 25232       True            4       2.0    False
# 25234       True            4       3.0    False
# 25236       True            4       5.0    False
# 25238       True            4       6.0    False
# 25239       True            4       7.0    False
# 25240      False            4       9.0    False
# 25241      False            4      10.0    False
# 25243       True            4      12.0    False
# 25244       True            4      13.0    False
# 25246       True            4      15.0    False
# 25248      False            4       1.0    False
# 25249      False            4      16.0    False
# 25250      False            4      17.0    False
# 25251      False            4       2.0    False
# 25252      False            4       3.0    False
# 25253      False            4       4.0    False
# 25254      False            4       5.0    False
# 25255      False            4       6.0    False
# 25256      False            4       7.0    False
# 25257      False            4       8.0    False
# 25258      False            4      10.0    False
# 25259      False            4       9.0    False
# 25260      False            4      11.0    False
# 25261      False            4      12.0    False
# 25262      False            4      13.0    False
# 25263      False            4      14.0    False
# 25264      False            4      15.0    False
# 26017       True            1      16.0    False
# 26132       True           12      16.0     True
#
#                         DeletedReason  FastF1Generated  IsAccurate
# 3245                              NaN            False       False
# 6252                              NaN            False       False
# 23058                             NaN            False       False
# 23119                             NaN            False       False
# 23127                             NaN            False       False
# 23915                             NaN            False       False
# 24773                             NaN            False       False
# 25230                             NaN            False       False
# 25231                             NaN            False       False
# 25232                             NaN            False       False
# 25234                             NaN            False       False
# 25236                             NaN            False       False
# 25238                             NaN            False       False
# 25239                             NaN            False       False
# 25240                             NaN            False       False
# 25241                             NaN            False       False
# 25243                             NaN            False       False
# 25244                             NaN            False       False
# 25246                             NaN            False       False
# 25248                             NaN            False       False
# 25249                             NaN            False       False
# 25250                             NaN            False       False
# 25251                             NaN            False       False
# 25252                             NaN            False       False
# 25253                             NaN            False       False
# 25254                             NaN            False       False
# 25255                             NaN            False       False
# 25256                             NaN            False       False
# 25257                             NaN            False       False
# 25258                             NaN            False       False
# 25259                             NaN            False       False
# 25260                             NaN            False       False
# 25261                             NaN            False       False
# 25262                             NaN            False       False
# 25263                             NaN            False       False
# 25264                             NaN            False       False
# 26017                             NaN            False       False
# 26132  TRACK LIMITS AT TURN 6 LAP 30             False       False
#
# [38 rows x 32 columns]

# %% [markdown]
# #### Ejemplo de salida a boxes

# %%
carreras_24[carreras_24['Driver']=='ALB'][['LapNumber','PitOutTime','PitInTime', 'EventName']].head(30)
# Out:
#      LapNumber             PitOutTime              PitInTime  \
# 12           1                    NaT                    NaT
# 30           2                    NaT                    NaT
# 50           3                    NaT                    NaT
# 70           4                    NaT                    NaT
# 90           5                    NaT                    NaT
# 110          6                    NaT                    NaT
# 130          7                    NaT                    NaT
# 150          8                    NaT                    NaT
# 170          9                    NaT                    NaT
# 190         10                    NaT                    NaT
# 210         11                    NaT                    NaT
# 230         12                    NaT                    NaT
# 247         13                    NaT                    NaT
# 264         14                    NaT                    NaT
# 283         15                    NaT 0 days 01:24:47.139000
# 303         16 0 days 01:25:11.918000                    NaT
# 334         17                    NaT                    NaT
# 353         18                    NaT                    NaT
# 373         19                    NaT                    NaT
# 393         20                    NaT                    NaT
# 413         21                    NaT                    NaT
# 433         22                    NaT                    NaT
# 453         23                    NaT                    NaT
# 473         24                    NaT                    NaT
# 493         25                    NaT                    NaT
# 513         26                    NaT                    NaT
# 533         27                    NaT                    NaT
# 553         28                    NaT                    NaT
# 572         29                    NaT                    NaT
# 591         30                    NaT                    NaT
#
#               EventName
# 12   Bahrain Grand Prix
# 30   Bahrain Grand Prix
# 50   Bahrain Grand Prix
# 70   Bahrain Grand Prix
# 90   Bahrain Grand Prix
# 110  Bahrain Grand Prix
# 130  Bahrain Grand Prix
# 150  Bahrain Grand Prix
# 170  Bahrain Grand Prix
# 190  Bahrain Grand Prix
# 210  Bahrain Grand Prix
# 230  Bahrain Grand Prix
# 247  Bahrain Grand Prix
# 264  Bahrain Grand Prix
# 283  Bahrain Grand Prix
# 303  Bahrain Grand Prix
# 334  Bahrain Grand Prix
# 353  Bahrain Grand Prix
# 373  Bahrain Grand Prix
# 393  Bahrain Grand Prix
# 413  Bahrain Grand Prix
# 433  Bahrain Grand Prix
# 453  Bahrain Grand Prix
# 473  Bahrain Grand Prix
# 493  Bahrain Grand Prix
# 513  Bahrain Grand Prix
# 533  Bahrain Grand Prix
# 553  Bahrain Grand Prix
# 572  Bahrain Grand Prix
# 591  Bahrain Grand Prix

# %% [markdown]
# Creamos nueva variable 'PitTime_seconds' que guarda el tiempo de parada en boxes

# %%
carreras_24 = carreras_24.sort_values(by=['EventName', 'Driver', 'LapNumber'])

# PitIn-Out
carreras_24['PitOutTime2'] = carreras_24.groupby(['EventName', 'Driver'], observed=True)['PitOutTime'].shift(-1)
carreras_24['PitTime'] = carreras_24['PitOutTime2'] - carreras_24['PitInTime']
carreras_24['PitTime_seconds'] = carreras_24['PitTime'].dt.total_seconds()

carreras_24.head()
# Out:
#                   EventName  EventDate Driver DriverNumber      Team  \
# 25580  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25605  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25624  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25643  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25662  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
#
#       PitInTime PitOutTime IsPersonalBest Stint  LapTime  ...  FreshTyre  \
# 25580       NaT        NaT          False   1.0  101.190  ...       True
# 25605       NaT        NaT           True   1.0  120.191  ...       True
# 25624       NaT        NaT           True   1.0   95.776  ...       True
# 25643       NaT        NaT           True   1.0   90.060  ...       True
# 25662       NaT        NaT          False   1.0   90.369  ...       True
#
#        TrackStatus Position  Deleted  DeletedReason  FastF1Generated  \
# 25580           12     16.0    False            NaN            False
# 25605           26     15.0    False            NaN            False
# 25624          671     15.0    False            NaN            False
# 25643            1     15.0    False            NaN            False
# 25662            1     15.0    False            NaN            False
#
#        IsAccurate  PitOutTime2  PitTime  PitTime_seconds
# 25580       False          NaT      NaT              NaN
# 25605       False          NaT      NaT              NaN
# 25624       False          NaT      NaT              NaN
# 25643        True          NaT      NaT              NaN
# 25662        True          NaT      NaT              NaN
#
# [5 rows x 35 columns]

# %%
# Verifico que la nueva columna PitTime no tenga valores nulos
carreras_24[(carreras_24['PitTime_seconds'].notnull())].shape
# Out:
# (824, 35)

# %% [markdown]
# Aplico imputación con 0s a los NaN de 'PitTime_seconds' y creo una nueva variable binaria 'Pit' que indica si el piloto hizo una parada en boxes o no.

# %%
# Creo nueva variable binaria
carreras_24['Pit'] = np.where(carreras_24['PitTime_seconds'].isnull(), 0, 1)

# Verifico que para no nulos en PitTime haya un 1 en Pit
carreras_24[(carreras_24['PitTime_seconds'].notnull())].head()
# Out:
#                   EventName  EventDate Driver DriverNumber          Team  \
# 25794  Abu Dhabi Grand Prix 2024-12-08    ALB           23      Williams
# 25807  Abu Dhabi Grand Prix 2024-12-08    ALO           14  Aston Martin
# 26248  Abu Dhabi Grand Prix 2024-12-08    ALO           14  Aston Martin
# 25679  Abu Dhabi Grand Prix 2024-12-08    BOT           77   Kick Sauber
# 25627  Abu Dhabi Grand Prix 2024-12-08    COL           43      Williams
#
#                    PitInTime PitOutTime IsPersonalBest Stint  LapTime  ...  \
# 25794 0 days 01:15:40.720000        NaT          False   1.0   92.201  ...
# 25807 0 days 01:17:02.713000        NaT          False   1.0   93.244  ...
# 26248 0 days 01:53:23.943000        NaT          False   2.0   91.999  ...
# 25679 0 days 01:06:36.737000        NaT          False   1.0   93.388  ...
# 25627 0 days 01:02:42.334000        NaT          False   1.0  130.710  ...
#
#        TrackStatus  Position Deleted  DeletedReason  FastF1Generated  \
# 25794            1      14.0   False            NaN            False
# 25807            1       8.0   False            NaN            False
# 26248            1       9.0   False            NaN            False
# 25679            1      16.0   False            NaN            False
# 25627          671      19.0   False            NaN            False
#
#        IsAccurate            PitOutTime2                PitTime  \
# 25794       False 0 days 01:16:02.774000 0 days 00:00:22.054000
# 25807       False 0 days 01:17:26.460000 0 days 00:00:23.747000
# 26248       False 0 days 01:53:46.293000 0 days 00:00:22.350000
# 25679       False 0 days 01:07:17.835000 0 days 00:00:41.098000
# 25627       False 0 days 01:03:07.286000 0 days 00:00:24.952000
#
#        PitTime_seconds  Pit
# 25794           22.054    1
# 25807           23.747    1
# 26248           22.350    1
# 25679           41.098    1
# 25627           24.952    1
#
# [5 rows x 36 columns]

# %%
# Verifico que para nulos en PitTime haya un 0 en Pit
carreras_24[(carreras_24['PitTime_seconds'].isnull())].head()
# Out:
#                   EventName  EventDate Driver DriverNumber      Team  \
# 25580  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25605  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25624  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25643  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
# 25662  Abu Dhabi Grand Prix 2024-12-08    ALB           23  Williams
#
#       PitInTime PitOutTime IsPersonalBest Stint  LapTime  ...  TrackStatus  \
# 25580       NaT        NaT          False   1.0  101.190  ...           12
# 25605       NaT        NaT           True   1.0  120.191  ...           26
# 25624       NaT        NaT           True   1.0   95.776  ...          671
# 25643       NaT        NaT           True   1.0   90.060  ...            1
# 25662       NaT        NaT          False   1.0   90.369  ...            1
#
#        Position Deleted  DeletedReason  FastF1Generated  IsAccurate  \
# 25580      16.0   False            NaN            False       False
# 25605      15.0   False            NaN            False       False
# 25624      15.0   False            NaN            False       False
# 25643      15.0   False            NaN            False        True
# 25662      15.0   False            NaN            False        True
#
#        PitOutTime2  PitTime  PitTime_seconds  Pit
# 25580          NaT      NaT              NaN    0
# 25605          NaT      NaT              NaN    0
# 25624          NaT      NaT              NaN    0
# 25643          NaT      NaT              NaN    0
# 25662          NaT      NaT              NaN    0
#
# [5 rows x 36 columns]

# %%
# Verifico que para nulos en PitTime haya un 0 en Pit
no_pit = len(carreras_24[(carreras_24['Pit']==0)])
is_pit = len(carreras_24[(carreras_24['Pit']==1)])
print(f"Cantidad de filas con Pit=0: {no_pit}")
print(f"Cantidad de filas con Pit=1: {is_pit}")
print(f"Total:{no_pit+is_pit}")
# Out:
# Cantidad de filas con Pit=0: 25782
# Cantidad de filas con Pit=1: 824
# Total:26606

# %%
# Aplico imputación a los valores nulos 
carreras_24['PitTime_seconds'] = pd.to_numeric(carreras_24['PitTime_seconds'], errors='coerce').fillna(0)

# Verifico
carreras_24[(carreras_24['PitTime_seconds'].isnull())].shape
# Out:
# (0, 36)

# %% [markdown]
# ---
# ## Outliers
#
# Estudio de outliers en PitTime_seconds.

# %%
carreras_24[carreras_24['Pit']==1]['PitTime_seconds'].describe(percentiles=[.9, .95, .99])
# Out:
# count     824.000000
# mean      131.575460
# std       431.692334
# min        15.747000
# 50%        23.536500
# 90%        34.710000
# 95%      1420.269050
# 99%      2376.832380
# max      2393.833000
# Name: PitTime_seconds, dtype: float64

# %% [markdown]
# #### Solo el 1% tiene valores no esperados (muy altos!)

# %%
carreras_24_f = carreras_24[(carreras_24['Pit']==1) & (carreras_24['PitTime_seconds'] < 50)]
carreras_24_f['PitTime_seconds'].describe()

# Boxplot por Driver
plt.figure(figsize=(12, 6))
sns.boxplot(x='Driver', y='PitTime_seconds', data=carreras_24_f)
plt.title('Boxplot of Pit Time by Driver (in seconds)')
plt.xlabel('Driver')
plt.ylabel('Pit Time (seconds)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### ¿Podemos asumir que son legítimos?

# %%
# outliers
df = carreras_24
df[df['PitTime_seconds'] >= 100][['EventName', 'Driver', 'LapNumber','PitInTime', 'PitOutTime2', 'PitTime_seconds', 'LapTime']]
# Out:
#                   EventName Driver  LapNumber              PitInTime  \
# 3031    Japanese Grand Prix    ALO          1 0 days 01:04:59.334000
# 3040    Japanese Grand Prix    BOT          1 0 days 01:05:22.020000
# 3042    Japanese Grand Prix    GAS          1 0 days 01:05:29.811000
# 3034    Japanese Grand Prix    HAM          1 0 days 01:05:11.331000
# 3045    Japanese Grand Prix    HUL          1 0 days 01:05:20.087000
# 3029    Japanese Grand Prix    LEC          1 0 days 01:05:12.799000
# 3039    Japanese Grand Prix    MAG          1 0 days 01:05:39.276000
# 3030    Japanese Grand Prix    NOR          1 0 days 01:04:53.865000
# 3041    Japanese Grand Prix    OCO          1 0 days 01:05:27.302000
# 3046    Japanese Grand Prix    PER          1 0 days 01:04:51.966000
# 3033    Japanese Grand Prix    PIA          1 0 days 01:05:02.858000
# 3032    Japanese Grand Prix    RUS          1 0 days 01:05:17.166000
# 3036    Japanese Grand Prix    SAI          1 0 days 01:04:56.098000
# 3043    Japanese Grand Prix    SAR          1 0 days 01:05:42.536000
# 3038    Japanese Grand Prix    STR          1 0 days 01:05:34.947000
# 3037    Japanese Grand Prix    TSU          1 0 days 01:05:24.893000
# 3028    Japanese Grand Prix    VER          1 0 days 01:04:49.856000
# 3044    Japanese Grand Prix    ZHO          1 0 days 01:05:49.692000
# 7323      Monaco Grand Prix    ALB          1 0 days 00:57:00.668000
# 7333      Monaco Grand Prix    ALO          1 0 days 00:57:10.782000
# 7327      Monaco Grand Prix    BOT          1 0 days 00:57:14.608000
# 7325      Monaco Grand Prix    GAS          1 0 days 00:57:02.934000
# 7320      Monaco Grand Prix    HAM          1 0 days 00:56:55.473000
# 7316      Monaco Grand Prix    LEC          1 0 days 00:56:45.433000
# 7317      Monaco Grand Prix    NOR          1 0 days 00:56:49.559000
# 7334      Monaco Grand Prix    PIA          1 0 days 00:56:48.100000
# 7326      Monaco Grand Prix    RIC          1 0 days 00:57:09.029000
# 7318      Monaco Grand Prix    RUS          1 0 days 00:56:51.329000
# 7324      Monaco Grand Prix    SAI          1 0 days 00:57:22.741000
# 7329      Monaco Grand Prix    SAR          1 0 days 00:57:12.277000
# 7328      Monaco Grand Prix    STR          1 0 days 00:57:06.173000
# 7321      Monaco Grand Prix    TSU          1 0 days 00:56:58.053000
# 7319      Monaco Grand Prix    VER          1 0 days 00:56:53.182000
# 7330      Monaco Grand Prix    ZHO          1 0 days 00:57:26.533000
# 23120  São Paulo Grand Prix    ALO         32 0 days 02:00:58.391000
# 23126  São Paulo Grand Prix    BEA         32 0 days 02:01:13.837000
# 23123  São Paulo Grand Prix    BOT         32 0 days 02:01:08.368000
# 23113  São Paulo Grand Prix    GAS         32 0 days 02:00:42.932000
# 23122  São Paulo Grand Prix    HAM         32 0 days 02:01:02.996000
# 23121  São Paulo Grand Prix    LAW         32 0 days 02:01:01.403000
# 23117  São Paulo Grand Prix    LEC         32 0 days 02:00:53.387000
# 23114  São Paulo Grand Prix    NOR         32 0 days 02:00:44.010000
# 23110  São Paulo Grand Prix    OCO         32 0 days 02:00:35.467000
# 23125  São Paulo Grand Prix    PER         32 0 days 02:01:11.572000
# 23118  São Paulo Grand Prix    PIA         32 0 days 02:00:56.326000
# 23115  São Paulo Grand Prix    RUS         32 0 days 02:00:49.338000
# 23124  São Paulo Grand Prix    SAI         32 0 days 02:01:09.712000
# 23116  São Paulo Grand Prix    TSU         32 0 days 02:00:50.960000
# 23111  São Paulo Grand Prix    VER         32 0 days 02:00:37.713000
# 23112  São Paulo Grand Prix    ZHO         31 0 days 02:00:40.326000
#
#                  PitOutTime2  PitTime_seconds   LapTime
# 3031  0 days 01:31:20.261000         1580.927   140.526
# 3040  0 days 01:31:44.274000         1582.254   164.736
# 3042  0 days 01:31:56.442000         1586.631   173.223
# 3034  0 days 01:31:32.133000         1580.802   152.716
# 3045  0 days 01:31:40.905000         1580.818   162.853
# 3029  0 days 01:31:36.027000         1583.228   154.543
# 3039  0 days 01:32:03.600000         1584.324   185.172
# 3030  0 days 01:31:13.972000         1580.107   134.751
# 3041  0 days 01:31:53.245000         1585.943   170.167
# 3046  0 days 01:31:09.531000         1577.565   132.767
# 3033  0 days 01:31:23.095000         1580.237   144.356
# 3032  0 days 01:31:38.368000         1581.202   159.587
# 3036  0 days 01:31:16.209000         1580.111   137.613
# 3043  0 days 01:32:07.166000         1584.630   188.456
# 3038  0 days 01:32:00.427000         1585.480   179.595
# 3037  0 days 01:31:48.957000         1584.064   167.566
# 3028  0 days 01:31:05.329000         1575.473   130.735
# 3044         0 days 01:32:12         1582.308   195.118
# 7323  0 days 01:36:41.722000         2381.054  2494.817
# 7333  0 days 01:37:00.031000         2389.249  2513.184
# 7327  0 days 01:37:08.441000         2393.833  2521.748
# 7325  0 days 01:36:44.525000         2381.591  2497.695
# 7320  0 days 01:36:30.616000         2375.143  2483.804
# 7316  0 days 01:36:03.182000         2357.749  2456.330
# 7317  0 days 01:36:14.893000         2365.334  2468.042
# 7334  0 days 01:36:05.541000         2357.441  2458.744
# 7326  0 days 01:36:54.504000         2385.475  2507.607
# 7318  0 days 01:36:20.812000         2369.483  2473.884
# 7324  0 days 01:36:09.554000         2326.813  2462.721
# 7329  0 days 01:37:03.705000         2391.428  2516.858
# 7328  0 days 01:36:49.541000         2383.368  2502.648
# 7321  0 days 01:36:35.390000         2377.337  2488.609
# 7319  0 days 01:36:25.661000         2372.479  2478.944
# 7330  0 days 01:37:13.050000         2386.517  2526.253
# 23120 0 days 02:24:41.305000         1422.914       NaN
# 23126 0 days 02:24:58.613000         1424.776       NaN
# 23123 0 days 02:24:50.479000         1422.111       NaN
# 23113 0 days 02:24:10.476000         1407.544       NaN
# 23122 0 days 02:24:48.717000         1425.721       NaN
# 23121 0 days 02:24:44.043000         1422.640       NaN
# 23117 0 days 02:24:33.679000         1420.292       NaN
# 23114 0 days 02:24:19.374000         1415.364       NaN
# 23110 0 days 02:24:04.195000         1408.728       NaN
# 23125 0 days 02:24:56.818000         1425.246       NaN
# 23118 0 days 02:24:36.465000         1420.139       NaN
# 23115 0 days 02:24:25.205000         1415.867       NaN
# 23124 0 days 02:24:54.333000         1424.621       NaN
# 23116 0 days 02:24:29.975000         1419.015       NaN
# 23111 0 days 02:24:06.937000         1409.224       NaN
# 23112 0 days 02:22:03.366000         1283.040       NaN

# %% [markdown]
# #### Análisis de nulos de LapTime

# %% [markdown]
#  Teniendo en cuenta que LapTime es la suma de los tramos Sector1Time, Sector2Time y Sector3Time, hay registros sin datos en absoluto?

# %%
# Miro los tiempos. Hay información?
todo_nulo = carreras_24[['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']].isna().all(axis=1)
print(f"Cantidad de filas con los 4 campos nulos: {todo_nulo.sum()}")
carreras_24[todo_nulo]
# Out:
# Cantidad de filas con los 4 campos nulos: 29
#                       EventName  EventDate Driver DriverNumber  \
# 26585      Abu Dhabi Grand Prix 2024-12-08    LAW           30
# 25586      Abu Dhabi Grand Prix 2024-12-08    PER           11
# 2314      Australian Grand Prix 2024-03-24    HAM           44
# 3008      Australian Grand Prix 2024-03-24    RUS           63
# 19073     Azerbaijan Grand Prix 2024-09-15    PER           11
# 19074     Azerbaijan Grand Prix 2024-09-15    SAI           55
# 12559        British Grand Prix 2024-07-07    GAS           10
# 9563        Canadian Grand Prix 2024-06-09    ALB           23
# 9033        Canadian Grand Prix 2024-06-09    SAR            2
# 4325         Chinese Grand Prix 2024-04-21    BOT           77
# 4462         Chinese Grand Prix 2024-04-21    TSU           22
# 3047        Japanese Grand Prix 2024-04-07    ALB           23
# 3035        Japanese Grand Prix 2024-04-07    RIC            3
# 3087        Japanese Grand Prix 2024-04-07    TSU           22
# 21347    Mexico City Grand Prix 2024-10-27    ALB           23
# 21359    Mexico City Grand Prix 2024-10-27    TSU           22
# 5524           Miami Grand Prix 2024-05-05    SAR            2
# 7322          Monaco Grand Prix 2024-05-26    HUL           27
# 7335          Monaco Grand Prix 2024-05-26    MAG           20
# 7331          Monaco Grand Prix 2024-05-26    OCO           31
# 7332          Monaco Grand Prix 2024-05-26    PER           11
# 24646          Qatar Grand Prix 2024-12-01    COL           43
# 25313          Qatar Grand Prix 2024-12-01    HUL           27
# 24639          Qatar Grand Prix 2024-12-01    OCO           31
# 25288          Qatar Grand Prix 2024-12-01    PER           11
# 1233   Saudi Arabian Grand Prix 2024-03-09    STR           18
# 23236      São Paulo Grand Prix 2024-11-03    SAI           55
# 22556      São Paulo Grand Prix 2024-11-03    STR           18
# 20312  United States Grand Prix 2024-10-20    HAM           44
#
#                   Team PitInTime PitOutTime IsPersonalBest Stint  LapTime  \
# 26585               RB       NaT        NaT            NaN   4.0      NaN
# 25586  Red Bull Racing       NaT        NaT          False   1.0      NaN
# 2314          Mercedes       NaT        NaT            NaN   2.0      NaN
# 3008          Mercedes       NaT        NaT            NaN   3.0      NaN
# 19073  Red Bull Racing       NaT        NaT            NaN   2.0      NaN
# 19074          Ferrari       NaT        NaT            NaN   2.0      NaN
# 12559           Alpine       NaT        NaT          False   1.0      NaN
# 9563          Williams       NaT        NaT            NaN   3.0      NaN
# 9033          Williams       NaT        NaT            NaN   1.0      NaN
# 4325       Kick Sauber       NaT        NaT            NaN   2.0      NaN
# 4462                RB       NaT        NaT            NaN   3.0      NaN
# 3047          Williams       NaT        NaT          False   1.0      NaN
# 3035                RB       NaT        NaT          False   1.0      NaN
# 3087                RB       NaT        NaT          False   2.0      NaN
# 21347         Williams       NaT        NaT          False   1.0      NaN
# 21359               RB       NaT        NaT          False   1.0      NaN
# 5524          Williams       NaT        NaT            NaN   2.0      NaN
# 7322      Haas F1 Team       NaT        NaT          False   1.0      NaN
# 7335      Haas F1 Team       NaT        NaT          False   1.0      NaN
# 7331            Alpine       NaT        NaT          False   1.0      NaN
# 7332   Red Bull Racing       NaT        NaT          False   1.0      NaN
# 24646         Williams       NaT        NaT          False   1.0      NaN
# 25313     Haas F1 Team       NaT        NaT            NaN   5.0      NaN
# 24639           Alpine       NaT        NaT          False   1.0      NaN
# 25288  Red Bull Racing       NaT        NaT            NaN   4.0      NaN
# 1233      Aston Martin       NaT        NaT            NaN   1.0      NaN
# 23236          Ferrari       NaT        NaT            NaN   3.0      NaN
# 22556     Aston Martin       NaT        NaT          False   1.0      NaN
# 20312         Mercedes       NaT        NaT            NaN   1.0      NaN
#
#        ...  TrackStatus  Position Deleted  DeletedReason  FastF1Generated  \
# 26585  ...           12       NaN   False            NaN             True
# 25586  ...           12       NaN   False            NaN             True
# 2314   ...           12       NaN   False            NaN             True
# 3008   ...            1       NaN   False            NaN             True
# 19073  ...            1       NaN   False            NaN             True
# 19074  ...            1       NaN   False            NaN             True
# 12559  ...            1       NaN   False            NaN             True
# 9563   ...           12       NaN   False            NaN             True
# 9033   ...            1       NaN   False            NaN             True
# 4325   ...           12       NaN   False            NaN             True
# 4462   ...           12       NaN   False            NaN             True
# 3047   ...          125       NaN   False            NaN             True
# 3035   ...          125       NaN   False            NaN             True
# 3087   ...            1       9.0   False            NaN            False
# 21347  ...          124       NaN   False            NaN             True
# 21359  ...          124       NaN   False            NaN             True
# 5524   ...            1       NaN   False            NaN             True
# 7322   ...         1254       NaN   False            NaN             True
# 7335   ...         1254       NaN   False            NaN             True
# 7331   ...         1254       NaN   False            NaN             True
# 7332   ...         1254       NaN   False            NaN             True
# 24646  ...          124       NaN   False            NaN             True
# 25313  ...          126       NaN   False            NaN             True
# 24639  ...          124       NaN   False            NaN             True
# 25288  ...          412       NaN   False            NaN             True
# 1233   ...            1       NaN   False            NaN             True
# 23236  ...            1       NaN   False            NaN             True
# 22556  ...           12       NaN   False            NaN             True
# 20312  ...            1       NaN   False            NaN             True
#
#        IsAccurate  PitOutTime2  PitTime  PitTime_seconds  Pit
# 26585       False          NaT      NaT              0.0    0
# 25586       False          NaT      NaT              0.0    0
# 2314        False          NaT      NaT              0.0    0
# 3008        False          NaT      NaT              0.0    0
# 19073       False          NaT      NaT              0.0    0
# 19074       False          NaT      NaT              0.0    0
# 12559       False          NaT      NaT              0.0    0
# 9563        False          NaT      NaT              0.0    0
# 9033        False          NaT      NaT              0.0    0
# 4325        False          NaT      NaT              0.0    0
# 4462        False          NaT      NaT              0.0    0
# 3047        False          NaT      NaT              0.0    0
# 3035        False          NaT      NaT              0.0    0
# 3087        False          NaT      NaT              0.0    0
# 21347       False          NaT      NaT              0.0    0
# 21359       False          NaT      NaT              0.0    0
# 5524        False          NaT      NaT              0.0    0
# 7322        False          NaT      NaT              0.0    0
# 7335        False          NaT      NaT              0.0    0
# 7331        False          NaT      NaT              0.0    0
# 7332        False          NaT      NaT              0.0    0
# 24646       False          NaT      NaT              0.0    0
# 25313       False          NaT      NaT              0.0    0
# 24639       False          NaT      NaT              0.0    0
# 25288       False          NaT      NaT              0.0    0
# 1233        False          NaT      NaT              0.0    0
# 23236       False          NaT      NaT              0.0    0
# 22556       False          NaT      NaT              0.0    0
# 20312       False          NaT      NaT              0.0    0
#
# [29 rows x 36 columns]

# %% [markdown]
# #### Entonces:
#
# - Qué tipo de error es este?
# - Vale la pena imputar todos estos datos? O es mejor descartar estas 29 filas?

# %%
carreras_24.shape # antes
# Out:
# (26606, 36)

# %%
# Decidimos descartarlos:
todo_nulo = carreras_24[['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']].isna().all(axis=1)
carreras_24 = carreras_24[~todo_nulo]
carreras_24.shape # despues
# Out:
# (26577, 36)

# %% [markdown]
# Si todavía hay nulos, analizamos en detalle:
# ¿Es MCAR, MAR o MNAR? ¿Hay patrones?
#
# Cosas que podríamos mirar:
# 1) ¿La vuelta fue eliminada y por eso falta el LapTime?
# 2) ¿El piloto hizo una parada en boxes y por eso falta el LapTime?
# 3) ¿El piloto abandonó por falla técnica, choque, etc.?
# 4) ¿Hubo algún incidente?

# %%
missing_laptime = carreras_24[carreras_24['LapTime'].isna()]

missing_laptime[['Driver','EventName','LapTime','LapNumber', 'Sector1Time','Sector2Time','Sector3Time', 'Pit', 'Deleted', 'Position', 'TrackStatus']]
# Out:
#       Driver                 EventName  LapTime  LapNumber  Sector1Time  \
# 2088     VER     Australian Grand Prix      NaN          4       28.756
# 19096    ALB     Azerbaijan Grand Prix      NaN         51       65.644
# 19095    ALO     Azerbaijan Grand Prix      NaN         51       65.674
# 19099    BEA     Azerbaijan Grand Prix      NaN         51       67.759
# 19091    BOT     Azerbaijan Grand Prix      NaN         50       61.927
# ...      ...                       ...      ...        ...          ...
# 20370    STR  United States Grand Prix      NaN          5       35.565
# 20347    TSU  United States Grand Prix      NaN          4       36.915
# 20366    TSU  United States Grand Prix      NaN          5       35.010
# 20341    VER  United States Grand Prix      NaN          4       40.222
# 20360    VER  United States Grand Prix      NaN          5       40.279
#
#        Sector2Time  Sector3Time  Pit Deleted  Position TrackStatus
# 2088        18.353          NaN    0   False      19.0           1
# 19096       50.778       36.258    0   False       7.0           6
# 19095       51.447       35.155    0   False       6.0           6
# 19099       47.594       37.896    0   False      10.0           6
# 19091       53.881       36.543    0   False      16.0           6
# ...            ...          ...  ...     ...       ...         ...
# 20370       61.334       55.141    0   False      12.0          41
# 20347       57.693       55.655    0   False       8.0           4
# 20366       62.524       58.983    0   False       8.0          41
# 20341       58.115       53.159    0   False       2.0           4
# 20360       61.864       65.480    0   False       2.0          41
#
# [196 rows x 11 columns]

# %%
carreras_24['Deleted'].unique()
# Hay nulos porque la vuelta fue anulada? Deleted = 1
# Out:
# [False, True]
# Categories (2, bool): [False, True]

# %%
carreras_24[(carreras_24['Deleted']== True) & (carreras_24['LapTime'].isnull())]
# Out:
# Empty DataFrame
# Columns: [EventName, EventDate, Driver, DriverNumber, Team, PitInTime, PitOutTime, IsPersonalBest, Stint, LapTime, LapNumber, LapStartTime, LapStartDate, Sector1Time, Sector2Time, Sector3Time, SpeedI1, SpeedI2, SpeedFL, SpeedST, AirTemp, TrackTemp, Humidity, Compound, TyreLife, FreshTyre, TrackStatus, Position, Deleted, DeletedReason, FastF1Generated, IsAccurate, PitOutTime2, PitTime, PitTime_seconds, Pit]
# Index: []
#
# [0 rows x 36 columns]

# %%
# ¿Cuántos coinciden con NaN en la columna Position?
print(f"Cuántos coinciden con NaN en Position?: {missing_laptime[missing_laptime['Position'].isnull()].shape[0]}")

# ¿Cuántos de esos datos faltantes son por safety car o virtual safety car?
print(f"Cuántos coinciden con un virtual safety car o safety car?: {missing_laptime[(missing_laptime['TrackStatus'] == 6) | (missing_laptime['TrackStatus'] == 4)].shape[0]}")

# ¿Cuántos de esos datos faltantes coinciden con bandera roja?
print(f"Cuántos coinciden con bandera roja?: {missing_laptime[ (missing_laptime['TrackStatus'] == 5)].shape[0]}")

# ¿Cuántos de esos datos faltantes ocurrieron con pista normal?
print(f"¿Cuántos nulos con pista normal? (TrackStatus = 1) : {missing_laptime[(missing_laptime['TrackStatus'] == 1)].shape[0]}")
# Out:
# Cuántos coinciden con NaN en Position?: 0
# Cuántos coinciden con un virtual safety car o safety car?: 72
# Cuántos coinciden con bandera roja?: 0
# ¿Cuántos nulos con pista normal? (TrackStatus = 1) : 34

# %%
# Chequear si hay nulos por abandono (DNF)

# Encuentro la última vuelta válida de cada piloto en cada carrera
last_valid_lap = carreras_24[~carreras_24['LapTime'].isna()].groupby(['EventName', 'Driver'], observed=True)['LapNumber'].max()
# Nota: el ~ significa que invierto la condición, es decir, busco los que no son NaN

# Busco el número máximo de vueltas de cada carrera
max_laps_per_race = carreras_24.groupby('EventName', observed=True)['LapNumber'].max()

# Combinar para ver si el piloto terminó la carrera
dnf_info = last_valid_lap.reset_index().merge(
    max_laps_per_race.reset_index(), on='EventName', suffixes=('_driver', '_race')
)
dnf_info['DNF'] = dnf_info['LapNumber_driver'] < dnf_info['LapNumber_race']

dnf_info[dnf_info['DNF']==True]
# Out:
#                     EventName Driver  LapNumber_driver  LapNumber_race   DNF
# 0        Abu Dhabi Grand Prix    ALB                57              58  True
# 2        Abu Dhabi Grand Prix    BOT                30              58  True
# 3        Abu Dhabi Grand Prix    COL                26              58  True
# 4        Abu Dhabi Grand Prix    DOO                57              58  True
# 8        Abu Dhabi Grand Prix    LAW                55              58  True
# ..                        ...    ...               ...             ...   ...
# 450  United States Grand Prix    HAM                 1              56  True
# 456  United States Grand Prix    OCO                55              56  True
# 461  United States Grand Prix    STR                55              56  True
# 462  United States Grand Prix    TSU                55              56  True
# 464  United States Grand Prix    ZHO                55              56  True
#
# [191 rows x 5 columns]

# %%
# Combinar los datos DNF en el dataset principal
carreras_24 = carreras_24.merge(dnf_info[['EventName', 'Driver', 'LapNumber_driver', 'DNF']], 
                                on=['EventName', 'Driver'], how='left')

# Filtrar
carreras_24['Likely_DNF'] = carreras_24['LapNumber'] > carreras_24['LapNumber_driver']

carreras_24[carreras_24['LapTime'].isna() & carreras_24['Likely_DNF']]
# Out:
#                    EventName  EventDate Driver DriverNumber             Team  \
# 1971   Australian Grand Prix 2024-03-24    VER            1  Red Bull Racing
# 3484   Azerbaijan Grand Prix 2024-09-15    ALB           23         Williams
# 3535   Azerbaijan Grand Prix 2024-09-15    ALO           14     Aston Martin
# 3586   Azerbaijan Grand Prix 2024-09-15    BEA           50     Haas F1 Team
# 3636   Azerbaijan Grand Prix 2024-09-15    BOT           77      Kick Sauber
# 3687   Azerbaijan Grand Prix 2024-09-15    COL           43         Williams
# 3738   Azerbaijan Grand Prix 2024-09-15    GAS           10           Alpine
# 3789   Azerbaijan Grand Prix 2024-09-15    HAM           44         Mercedes
# 3840   Azerbaijan Grand Prix 2024-09-15    HUL           27     Haas F1 Team
# 3891   Azerbaijan Grand Prix 2024-09-15    LEC           16          Ferrari
# 3942   Azerbaijan Grand Prix 2024-09-15    NOR            4          McLaren
# 3992   Azerbaijan Grand Prix 2024-09-15    OCO           31           Alpine
# 4092   Azerbaijan Grand Prix 2024-09-15    PIA           81          McLaren
# 4142   Azerbaijan Grand Prix 2024-09-15    RIC            3               RB
# 4143   Azerbaijan Grand Prix 2024-09-15    RIC            3               RB
# 4194   Azerbaijan Grand Prix 2024-09-15    RUS           63         Mercedes
# 4352   Azerbaijan Grand Prix 2024-09-15    VER            1  Red Bull Racing
# 4353   Azerbaijan Grand Prix 2024-09-15    VER            1  Red Bull Racing
# 4403   Azerbaijan Grand Prix 2024-09-15    ZHO           24      Kick Sauber
# 4404   Azerbaijan Grand Prix 2024-09-15    ZHO           24      Kick Sauber
# 7777     Canadian Grand Prix 2024-06-09    LEC           16          Ferrari
# 8039     Canadian Grand Prix 2024-06-09    PER           11  Red Bull Racing
# 8302     Canadian Grand Prix 2024-06-09    SAI           55          Ferrari
# 24790   São Paulo Grand Prix 2024-11-03    HUL           27     Haas F1 Team
#
#                    PitInTime             PitOutTime IsPersonalBest Stint  \
# 1971  0 days 01:04:24.613000                    NaT          False   1.0
# 3484                     NaT                    NaT          False   2.0
# 3535                     NaT                    NaT          False   2.0
# 3586                     NaT                    NaT          False   2.0
# 3636                     NaT                    NaT          False   2.0
# 3687                     NaT                    NaT          False   2.0
# 3738                     NaT 0 days 02:28:45.096000          False   2.0
# 3789                     NaT                    NaT          False   2.0
# 3840                     NaT                    NaT          False   2.0
# 3891                     NaT                    NaT          False   2.0
# 3942                     NaT                    NaT          False   2.0
# 3992                     NaT 0 days 02:27:07.907000          False   2.0
# 4092                     NaT                    NaT          False   2.0
# 4142                     NaT 0 days 02:26:39.295000          False   2.0
# 4143                     NaT                    NaT          False   2.0
# 4194                     NaT                    NaT          False   2.0
# 4352                     NaT 0 days 02:25:38.947000          False   3.0
# 4353                     NaT                    NaT          False   3.0
# 4403                     NaT                    NaT          False   2.0
# 4404                     NaT                    NaT          False   2.0
# 7777  0 days 01:09:30.763000                    NaT          False   4.0
# 8039  0 days 01:24:22.873000                    NaT          False   3.0
# 8302  0 days 01:25:45.694000                    NaT          False   3.0
# 24790 0 days 02:01:05.310000 0 days 01:58:44.080000          False   4.0
#
#        LapTime  ...  DeletedReason  FastF1Generated IsAccurate  PitOutTime2  \
# 1971       NaN  ...            NaN            False      False          NaT
# 3484       NaN  ...            NaN            False      False          NaT
# 3535       NaN  ...            NaN            False      False          NaT
# 3586       NaN  ...            NaN            False      False          NaT
# 3636       NaN  ...            NaN            False      False          NaT
# 3687       NaN  ...            NaN            False      False          NaT
# 3738       NaN  ...            NaN            False      False          NaT
# 3789       NaN  ...            NaN            False      False          NaT
# 3840       NaN  ...            NaN            False      False          NaT
# 3891       NaN  ...            NaN            False      False          NaT
# 3942       NaN  ...            NaN            False      False          NaT
# 3992       NaN  ...            NaN            False      False          NaT
# 4092       NaN  ...            NaN            False      False          NaT
# 4142       NaN  ...            NaN            False      False          NaT
# 4143       NaN  ...            NaN            False      False          NaT
# 4194       NaN  ...            NaN            False      False          NaT
# 4352       NaN  ...            NaN            False      False          NaT
# 4353       NaN  ...            NaN            False      False          NaT
# 4403       NaN  ...            NaN            False      False          NaT
# 4404       NaN  ...            NaN            False      False          NaT
# 7777       NaN  ...            NaN            False      False          NaT
# 8039       NaN  ...            NaN            False      False          NaT
# 8302       NaN  ...            NaN            False      False          NaT
# 24790      NaN  ...            NaN            False      False          NaT
#
#        PitTime  PitTime_seconds  Pit  LapNumber_driver   DNF  Likely_DNF
# 1971       NaT              0.0    0                 3  True        True
# 3484       NaT              0.0    0                50  True        True
# 3535       NaT              0.0    0                50  True        True
# 3586       NaT              0.0    0                50  True        True
# 3636       NaT              0.0    0                49  True        True
# 3687       NaT              0.0    0                50  True        True
# 3738       NaT              0.0    0                50  True        True
# 3789       NaT              0.0    0                50  True        True
# 3840       NaT              0.0    0                50  True        True
# 3891       NaT              0.0    0                50  True        True
# 3942       NaT              0.0    0                50  True        True
# 3992       NaT              0.0    0                49  True        True
# 4092       NaT              0.0    0                50  True        True
# 4142       NaT              0.0    0                49  True        True
# 4143       NaT              0.0    0                49  True        True
# 4194       NaT              0.0    0                50  True        True
# 4352       NaT              0.0    0                49  True        True
# 4353       NaT              0.0    0                49  True        True
# 4403       NaT              0.0    0                49  True        True
# 4404       NaT              0.0    0                49  True        True
# 7777       NaT              0.0    0                40  True        True
# 8039       NaT              0.0    0                51  True        True
# 8302       NaT              0.0    0                52  True        True
# 24790      NaT              0.0    0                29  True        True
#
# [24 rows x 39 columns]

# %% [markdown]
# #### Imputación de LapTime

# %% [markdown]
# Imputo el valor de LapTime con la suma de los tramos Sector1Time, Sector2Time y Sector3Time.
# Primer paso - revisar LapTime nulo pero Sectores 1, 2 y 3 no nulos.

# %%
carreras_24[carreras_24['LapTime'].isnull() & carreras_24['Sector1Time'].notnull() & carreras_24['Sector2Time'].notnull() & carreras_24['Sector3Time'].notnull()].shape[0]
# Out:
# 144

# %%
# Imputar LapTime cuando los 3 tramos están disponibles

def imputar_laptime_con_sectores(row):
    if pd.isna(row['LapTime']) and pd.notna(row['Sector1Time']) and pd.notna(row['Sector2Time']) and pd.notna(row['Sector3Time']):
        return row['Sector1Time'] + row['Sector2Time'] + row['Sector3Time']
    return row['LapTime']

# Aplicar la imputación en la columna
carreras_24['LapTime'] = carreras_24.apply(imputar_laptime_con_sectores, axis=1)

# %%
print(f"Después de imputar, me quedaron {carreras_24['LapTime'].isnull().sum()} nulos")
# Out:
# Después de imputar, me quedaron 52 nulos

# %%
# Empiezo a explorar.
# Hay muchos de 'São Paulo Grand Prix', LapNumber 33. Miremos estos datos en el datast carreras_24

filtro=(carreras_24['EventName']=='São Paulo Grand Prix') & (carreras_24['LapNumber']==33)

carreras_24[filtro][['Driver','EventName','LapTime','LapNumber', 'Sector1Time','Sector2Time','Sector3Time', 'Pit', 'Deleted', 'Position', 'TrackStatus']]
# Out:
#       Driver             EventName  LapTime  LapNumber  Sector1Time  \
# 24418    ALO  São Paulo Grand Prix      NaN         33          NaN
# 24487    BEA  São Paulo Grand Prix      NaN         33          NaN
# 24556    BOT  São Paulo Grand Prix      NaN         33          NaN
# 24655    GAS  São Paulo Grand Prix      NaN         33          NaN
# 24724    HAM  São Paulo Grand Prix      NaN         33          NaN
# 24823    LAW  São Paulo Grand Prix      NaN         33          NaN
# 24892    LEC  São Paulo Grand Prix      NaN         33          NaN
# 24961    NOR  São Paulo Grand Prix      NaN         33          NaN
# 25030    OCO  São Paulo Grand Prix      NaN         33          NaN
# 25099    PER  São Paulo Grand Prix      NaN         33          NaN
# 25168    PIA  São Paulo Grand Prix      NaN         33          NaN
# 25237    RUS  São Paulo Grand Prix      NaN         33          NaN
# 25306    SAI  São Paulo Grand Prix      NaN         33          NaN
# 25344    TSU  São Paulo Grand Prix      NaN         33          NaN
# 25413    VER  São Paulo Grand Prix      NaN         33          NaN
# 25482    ZHO  São Paulo Grand Prix  173.772         33       92.763
#
#        Sector2Time  Sector3Time  Pit Deleted  Position TrackStatus
# 24418       52.890       41.155    0   False       9.0          12
# 24487       50.541       37.289    0   False      16.0          12
# 24556       50.935       34.379    0   False      12.0          12
# 24655       75.665       45.644    0   False       3.0          12
# 24724       50.945       39.008    0   False      11.0          12
# 24823       52.684       39.678    0   False      10.0          12
# 24892       57.893       42.197    0   False       7.0          12
# 24961       68.773       44.856    0   False       4.0          12
# 25030       75.860       46.895    0   False       1.0          12
# 25099       50.818       29.991    0   False      13.0          12
# 25168       54.107       41.616    0   False       8.0          12
# 25237       61.858       44.726    0   False       5.0          12
# 25306       50.818       32.285    0   False      14.0          12
# 25344       59.675       43.873    0   False       6.0          12
# 25413       75.809       46.384    0   False       2.0          12
# 25482       52.444       28.565    0   False      15.0          12

# %% [markdown]
# El Sector1Time es casi todo nulos en la vuelta 33.
#
# Miro las estadísticas de tiempos en sector 1, 2 y 3 para ver si hay un patrón que se pueda usar para imputar los tiempos de los sectores individuales.

# %%
# Filtrar el DataFrame por EventName
saopaulo_df = carreras_24[carreras_24['EventName'] == 'São Paulo Grand Prix']

# Convertir tiempos a segundos y eliminar NaNs
sector1_seconds = saopaulo_df['Sector1Time'].dropna()
sector2_seconds = saopaulo_df['Sector2Time'].dropna()
sector3_seconds = saopaulo_df['Sector3Time'].dropna()

fig, axs = plt.subplots(3, 1, figsize=(10, 12), sharex=False)

# Sector 1
axs[0].hist(sector1_seconds, bins=50, color='mediumseagreen', edgecolor='black')
axs[0].set_title('Sector 1 – São Paulo Grand Prix')
axs[0].set_ylabel('Frecuencia')
axs[0].grid(True)

# Sector 2
axs[1].hist(sector2_seconds, bins=50, color='cornflowerblue', edgecolor='black')
axs[1].set_title('Sector 2 – São Paulo Grand Prix')
axs[1].set_ylabel('Frecuencia')
axs[1].grid(True)

# Sector 3
axs[2].hist(sector3_seconds, bins=50, color='salmon', edgecolor='black')
axs[2].set_title('Sector 3 – São Paulo Grand Prix')
axs[2].set_xlabel('Tiempo en segundos')
axs[2].set_ylabel('Frecuencia')
axs[2].grid(True)

# Ajustar espacios
plt.tight_layout()
plt.show()

# %%
sector1_seconds.describe()
# Out:
# count    1098.000000
# mean       23.134933
# std         4.982124
# min        20.546000
# 25%        21.341250
# 50%        21.617000
# 75%        22.176500
# max        92.763000
# Name: Sector1Time, dtype: float64

# %%
sector2_seconds.describe()
# Out:
# count    1133.000000
# mean       47.007008
# std         5.710202
# min        42.236000
# 25%        44.165000
# 50%        44.958000
# 75%        46.237000
# max        75.860000
# Name: Sector2Time, dtype: float64

# %%
sector3_seconds.describe()
# Out:
# count    1133.000000
# mean       20.487071
# std         6.487737
# min        17.690000
# 25%        18.116000
# 50%        18.316000
# 75%        18.697000
# max        64.005000
# Name: Sector3Time, dtype: float64

# %%
# En los sectores 1 y 3 los datos están bastante concentrados, y tiene sentido imputar la mediana de ese valor en la misma carrera.
# En el sector 2 solo hay 3 nulos. No es tan relevante ni va a tener un impacto importante imputar también estos 3 con la mediana.

# Imputar Sector1Time, Sector2Time y Sector3Time por la mediana del mismo EventName
for sector in ['Sector1Time', 'Sector2Time', 'Sector3Time']:
    carreras_24[sector] = carreras_24[sector].fillna(
        carreras_24.groupby('EventName',observed=True)[sector].transform('median')
    )

# %%
# Vuelvo a aplicar la imputación en la columna LapTime para tratar los últimos faltantes.
carreras_24['LapTime'] = carreras_24.apply(imputar_laptime_con_sectores, axis=1)

# %%
carreras_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26577 entries, 0 to 26576
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EventName         26577 non-null  category
#  1   EventDate         26577 non-null  datetime64[ns]
#  2   Driver            26577 non-null  category
#  3   DriverNumber      26577 non-null  category
#  4   Team              26577 non-null  category
#  5   PitInTime         849 non-null    timedelta64[ns]
#  6   PitOutTime        840 non-null    timedelta64[ns]
#  7   IsPersonalBest    26577 non-null  category
#  8   Stint             26577 non-null  category
#  9   LapTime           26577 non-null  float64
#  10  LapNumber         26577 non-null  int64
#  11  LapStartTime      26577 non-null  float64
#  12  LapStartDate      26577 non-null  object
#  13  Sector1Time       26577 non-null  float64
#  14  Sector2Time       26577 non-null  float64
#  15  Sector3Time       26577 non-null  float64
#  16  SpeedI1           22460 non-null  float64
#  17  SpeedI2           26552 non-null  float64
#  18  SpeedFL           25728 non-null  float64
#  19  SpeedST           24422 non-null  float64
#  20  AirTemp           26577 non-null  float64
#  21  TrackTemp         26577 non-null  float64
#  22  Humidity          26577 non-null  float64
#  23  Compound          26577 non-null  category
#  24  TyreLife          26577 non-null  category
#  25  FreshTyre         26577 non-null  category
#  26  TrackStatus       26577 non-null  category
#  27  Position          26577 non-null  float64
#  28  Deleted           26577 non-null  category
#  29  DeletedReason     326 non-null    category
#  30  FastF1Generated   26577 non-null  bool
#  31  IsAccurate        26577 non-null  bool
#  32  PitOutTime2       824 non-null    timedelta64[ns]
#  33  PitTime           824 non-null    timedelta64[ns]
#  34  PitTime_seconds   26577 non-null  float64
#  35  Pit               26577 non-null  int64
#  36  LapNumber_driver  26577 non-null  int64
#  37  DNF               26577 non-null  bool
#  38  Likely_DNF        26577 non-null  bool
# dtypes: bool(4), category(12), datetime64[ns](1), float64(14), int64(3), object(1), timedelta64[ns](4)
# memory usage: 5.1+ MB

# %% [markdown]
# #### Análisis de la variable Position

# %%
carreras_24.isna().sum()
# Out:
# EventName               0
# EventDate               0
# Driver                  0
# DriverNumber            0
# Team                    0
# PitInTime           25728
# PitOutTime          25737
# IsPersonalBest          0
# Stint                   0
# LapTime                 0
# LapNumber               0
# LapStartTime            0
# LapStartDate            0
# Sector1Time             0
# Sector2Time             0
# Sector3Time             0
# SpeedI1              4117
# SpeedI2                25
# SpeedFL               849
# SpeedST              2155
# AirTemp                 0
# TrackTemp               0
# Humidity                0
# Compound                0
# TyreLife                0
# FreshTyre               0
# TrackStatus             0
# Position                0
# Deleted                 0
# DeletedReason       26251
# FastF1Generated         0
# IsAccurate              0
# PitOutTime2         25753
# PitTime             25753
# PitTime_seconds         0
# Pit                     0
# LapNumber_driver        0
# DNF                     0
# Likely_DNF              0
# dtype: int64

# %% [markdown]
# ---
# ### Algunas visualizaciones básicas

# %%
# ¿En cuántos equipos estuvo cada piloto?
teams = carreras_24.groupby('Driver', observed=True)['Team'].nunique().reset_index()
teams.plot(kind='bar', x='Driver', y='Team', figsize=(10, 4), legend=False)
plt.show()

# %%
# Total de carreras en las que participó cada piloto
driver_events = carreras_24.groupby('Driver', observed=True)['EventName'].nunique().reset_index()
driver_events = driver_events.sort_values(ascending=False, by='EventName')

driver_events.plot.barh(x='Driver', y='EventName', figsize=(8, 6))
plt.xlabel('Cantidad de eventos')
plt.title('Eventos por piloto')
plt.show()

# %%
#!conda install networkx

# %%
# Para cuántos equipos corre cada piloto?
import networkx as nx
from networkx.drawing.layout import bipartite_layout

# Crear grafo
G = nx.Graph()
pares = carreras_24[['Driver', 'Team']].drop_duplicates()
pilotos = pares['Driver'].unique()
equipos = pares['Team'].unique()

G.add_nodes_from(pilotos, bipartite=0)
G.add_nodes_from(equipos, bipartite=1)
G.add_edges_from(list(pares.itertuples(index=False, name=None)))

# Layout bipartito
pos = bipartite_layout(G, drivers)

# Figura
plt.figure(figsize=(10, 6))
nx.draw(G, pos,
        with_labels=True,
        node_size=2000,
        node_color=['#66c2a5' if n in drivers else '#fc8d62' for n in G.nodes()],
        edge_color='gray',
        font_size=8)

plt.title('Relación entre pilotos y equipos')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Datos por piloto y carrera
#
# - Posición en cada carrera
# - Total de tiempo de vuelta
# - Compuesto de neumáticos usados
# - Número de paradas y tiempo total de pits

# %%
# Métricas por piloto y por carrera
result = carreras_24.groupby(['Driver', 'EventName'], observed=True).agg(
    Position_start=('Position', 'first'),
    Position_end=('Position', 'last'),
    Total_LapTime=('LapTime', 'sum'),
    Tyre_Compound_start=('Compound', 'first'),
    Tyre_Compound_end=('Compound', 'last'),
    Total_PitTime=('PitTime_seconds', 'sum'), # Total de tiempo en boxes
    Pit_Stops=('PitInTime', lambda x: x.notna().sum()),
).reset_index()

# Info de las entradas a boxes
pit_laps = (
    carreras_24[carreras_24['PitInTime'].notna()]
    .groupby(['Driver', 'EventName'], observed=True)['LapNumber']
    .apply(list)
    .reset_index()
    .rename(columns={'LapNumber': 'Pit_LapNumbers'})
)
result = result.merge(pit_laps, on=['Driver', 'EventName'], how='left')
result['Pit_LapNumbers'] = result['Pit_LapNumbers'].apply(lambda x: x if isinstance(x, list) else [])

result.head()
# Out:
#   Driver              EventName  Position_start  Position_end  Total_LapTime  \
# 0    ALB   Abu Dhabi Grand Prix            16.0          11.0       5204.542
# 1    ALB  Australian Grand Prix            14.0          11.0       4831.852
# 2    ALB    Austrian Grand Prix            15.0          14.0       5073.664
# 3    ALB  Azerbaijan Grand Prix             9.0           7.0       5665.403
# 4    ALB     Bahrain Grand Prix            11.0          15.0       5516.628
#
#   Tyre_Compound_start Tyre_Compound_end  Total_PitTime  Pit_Stops  \
# 0              MEDIUM              HARD         22.054          1
# 1              MEDIUM              HARD         35.187          2
# 2              MEDIUM              HARD         43.397          2
# 3                HARD            MEDIUM         20.333          1
# 4                SOFT              HARD         49.461          2
#
#   Pit_LapNumbers
# 0           [12]
# 1        [6, 27]
# 2       [12, 39]
# 3           [31]
# 4       [15, 36]

# %% [markdown]
# ### Otros datos y métricas de interés
#
# - winners: ganadores de cada carrera
# - ranking: cantidad de carreras ganadas por piloto
# - ranking_top: el top 3 de pilotos ganadores
# - df_top: todas las carreras de los pilotos del top 3
# - ganadas: todas las carreras ganadas por los pilotos del top 3

# %%
# Ganadores de cada carrera
winners = result[['Driver', 'EventName']][result['Position_end']==1].sort_values(['Driver', 'EventName'])

# %%
# Top 3 ganadores
ranking = winners['Driver'].value_counts().reset_index()
ranking.columns = ['Driver', 'Wins']
# ranking = ranking.sort_values(by='Wins', ascending=False) # no es necesario, el value_counts() por defecto devuelve los datos ordenados.

ranking_top = ranking.head(3)
ranking_top
# Out:
#   Driver  Wins
# 0    VER     9
# 1    NOR     4
# 2    LEC     3

# %%
# Me quedo solo con las carreras de los 3 pilotos que más carreras ganaron
df_top = result[result['Driver'].isin(ranking_top['Driver'])]
df_top.head()
# Out:
#     Driver              EventName  Position_start  Position_end  \
# 157    LEC   Abu Dhabi Grand Prix             9.0           3.0
# 158    LEC  Australian Grand Prix             4.0           2.0
# 159    LEC    Austrian Grand Prix            18.0          11.0
# 160    LEC  Azerbaijan Grand Prix             1.0           2.0
# 161    LEC     Bahrain Grand Prix             2.0           4.0
#
#      Total_LapTime Tyre_Compound_start Tyre_Compound_end  Total_PitTime  \
# 157       5225.219              MEDIUM              HARD         21.933
# 158       4829.209              MEDIUM              HARD         34.387
# 159       5129.854              MEDIUM            MEDIUM         96.589
# 160       5588.917              MEDIUM              HARD         20.867
# 161       5544.411                SOFT              HARD         48.129
#
#      Pit_Stops   Pit_LapNumbers
# 157          1             [20]
# 158          2          [9, 34]
# 159          4  [1, 16, 33, 51]
# 160          1             [16]
# 161          2         [11, 34]

# %%
# Del top 3, solo las carreras donde cada piloto ganó

ganadas = df_top[df_top['Position_end'] == 1].copy()

ganadas['RacingTime'] = ganadas['Total_LapTime'] - ganadas['Total_PitTime']
ganadas['PitFraction'] = ganadas['Total_PitTime'] / ganadas['Total_LapTime']
ganadas['Position_Change'] = ganadas['Position_start'] - ganadas['Position_end']
ganadas['Compound_Strategy'] = ganadas['Tyre_Compound_start'].astype(str) + ' → ' + ganadas['Tyre_Compound_end'].astype(str)

ganadas['Driver'] = ganadas['Driver'].cat.remove_unused_categories()

ganadas.head()
# Out:
#     Driver                 EventName  Position_start  Position_end  \
# 169    LEC        Italian Grand Prix             2.0           1.0
# 174    LEC         Monaco Grand Prix             1.0           1.0
# 180    LEC  United States Grand Prix             1.0           1.0
# 202    NOR      Abu Dhabi Grand Prix             1.0           1.0
# 211    NOR          Dutch Grand Prix             2.0           1.0
#
#      Total_LapTime Tyre_Compound_start Tyre_Compound_end  Total_PitTime  \
# 169       4480.727              MEDIUM              HARD         24.419
# 174       8507.572              MEDIUM              HARD       2357.749
# 180       5709.639              MEDIUM              HARD         23.870
# 202       5193.291              MEDIUM              HARD         21.406
# 211       5445.519              MEDIUM              HARD         21.520
#
#      Pit_Stops Pit_LapNumbers  RacingTime  PitFraction  Position_Change  \
# 169          1           [15]    4456.308     0.005450              1.0
# 174          1            [1]    6149.823     0.277135              0.0
# 180          1           [26]    5685.769     0.004181              0.0
# 202          1           [26]    5171.885     0.004122              0.0
# 211          1           [28]    5423.999     0.003952              1.0
#
#     Compound_Strategy
# 169     MEDIUM → HARD
# 174     MEDIUM → HARD
# 180     MEDIUM → HARD
# 202     MEDIUM → HARD
# 211     MEDIUM → HARD

# %% [markdown]
# ### Más visualizaciones

# %%
# Preparamos los datos
comparacion = ganadas.melt(
    id_vars=['Driver', 'EventName', 'Pit_Stops'],
    value_vars=['RacingTime', 'Total_PitTime'],
    var_name='Tipo',
    value_name='Tiempo'
)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Primer gráfico: Barras de tiempo total
sns.barplot(data=comparacion, errorbar=None, estimator='sum', x='Driver', y='Tiempo', hue='Tipo', ax=axes[0])
axes[0].set_title('Tiempos en la carrera ganada: Pit vs Corriendo')
axes[0].set_ylabel('Tiempo (segundos)')
axes[0].set_xlabel('Piloto')
axes[0].legend(title='Tiempos', labels=['Tiempo en carrera', 'Tiempo en pits'])
axes[0].grid(axis='y', linestyle='--', alpha=0.5)

# Segundo gráfico: Fracción de tiempo en boxes
sns.barplot(data=ganadas, x='Driver', y='PitFraction', estimator='mean', ax=axes[1])
axes[1].set_title('Proporción promedio del tiempo en pits (carreras ganadas)')
axes[1].set_ylabel('Fracción del tiempo en boxes')
axes[1].set_xlabel('Piloto')
axes[1].set_ylim(0, 0.3)
axes[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
axes[1].grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
ganadas['Position_Change'] = ganadas['Position_start'] - ganadas['Position_end']

plt.figure(figsize=(6, 4))
sns.boxplot(
    data=ganadas,
    hue='Tyre_Compound_start',
    y='Position_Change',
    palette='Set2'
)
plt.axhline(0, linestyle='-', color='gray')
plt.title('Cambio de posición según neumático inicial')
plt.ylabel('Posiciones ganadas (+) o perdidas (–)')
plt.xlabel('Compuesto inicial')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %%
# Pivot con posición de largada
pivot = ganadas.pivot_table(
    index='Tyre_Compound_start',
    columns='Position_start',
    values='Position_Change',
    aggfunc='mean',
    observed=False
)

# Heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(pivot, annot=True, fmt=".1f", cmap="RdYlGn", center=0, linewidths=0.5, linecolor='lightgray')

plt.title("Posiciones ganadas según neumático inicial y posición de largada")
plt.xlabel("Posición de largada")
plt.ylabel("Neumático inicial")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Exportación para leer en otra Notebook

# %%
import json

# Detectar columnas categóricas
categorical_cols = [col for col, dtype in carreras_24.dtypes.items() if str(dtype) == 'category']

# Guardar los tipos como strings
dtypes_str = {col: str(dtype) for col, dtype in carreras_24.dtypes.items()}

# Guardar todo en un solo JSON
info = {
    "dtypes": dtypes_str,
    "categoricals": categorical_cols
}

with open("../datasets/carreras_24_dtypes.json", "w") as f:
    json.dump(info, f)

# exportar CSV
carreras_24.to_csv('../datasets/carreras_24.csv', index=False)
