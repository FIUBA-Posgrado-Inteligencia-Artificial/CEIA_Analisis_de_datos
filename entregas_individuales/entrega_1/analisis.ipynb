# %%
import pandas as pd

# %%
data=pd.read_csv("./data/1ersemestre2023.csv")
data.info()

# %%
data["TIPO DE CONSULTA"].value_counts()

# %%
data[(data["NO EFECTIVA DESCRIPCION"].notnull()) & (data["TIPO DE CONSULTA"] == "No Efectiva")]["NO EFECTIVA DESCRIPCION"].size

# %%
data[(data["NO EFECTIVA DESCRIPCION"].isna()) & (data["TIPO DE CONSULTA"] == "No Efectiva")]["NO EFECTIVA DESCRIPCION"].size

# %%
data["TIEMPO DE CONSUMO"].value_counts()

# %% [markdown]
# No tiene dos variables numericas

# %% [markdown]
# ---

# %% [markdown]
# ## Sedronar

# %%
from utils.mappers import map_columns,map_values
data = pd.read_csv("./data/base-estudio-hogares-2017.csv")

# %% [markdown]
# tiene demasiadas filas

# %% [markdown]
# ---

# %%
#https://www.datos.gob.ar/dataset/sedronar-primer-relevamiento-nacional-dispositivos---2022/archivo/sedronar_8.1
data = pd.read_csv('data/base-primer-relev-dispositivos.csv', encoding="latin-1")
data.info()

# %%
data["q0038_0001_0001"][1797]
